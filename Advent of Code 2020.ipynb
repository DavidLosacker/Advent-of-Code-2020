# %% [markdown]
# # Day 1

# %%
with open("Day_1_list.txt", "r") as f:
    information = f.read()

# %%
info_list = information.split('\n')

# %%
for information_1 in info_list:
    for information_2 in info_list:
        if int(information_1) + int(information_2) == 2020:
            print(information_1, information_2)
            print(int(information_1) * int(information_2))

# %%
for information_1 in info_list:
    for information_2 in info_list:
        for information_3 in info_list:
            if int(information_1) + int(information_2) + int(information_3) == 2020:
                print(information_1, information_2, information_3)
                print(int(information_1) * int(information_2) * int(information_3))

# %% [markdown]
# # Day 2

# %%
with open("Day_2_list.txt", "r") as f:
    passwords = f.read()
    
password_list = passwords.split('\n')

# %%
counter = 0

for password in password_list:
    letter_min = int(password.split('-')[0])
    letter_max = int(password.split('-')[1].split(' ')[0])
    letter = password.split('-')[1].split(' ')[1][0]
    password_string = password.split(':')[1]
    character_counter = 0
    for character in password_string:
        if letter == character:
            character_counter += 1
    if character_counter >= letter_min and character_counter <= letter_max:
        counter += 1
print(counter)

# %%
counter = 0

for password in password_list:
    letter_min = int(password.split('-')[0])
    letter_max = int(password.split('-')[1].split(' ')[0])
    letter = password.split('-')[1].split(' ')[1][0]
    password_string = password.split(':')[1]
    if ((password_string[letter_min] == letter) != (password_string[letter_max] == letter)):
        counter += 1
        
print(counter)

# %% [markdown]
# # Day 3

# %%
with open("Day_3_list.txt", "r") as f:
    tree_map = f.read()

# %%
tree_map_list = tree_map.split('\n')

# %%
downway = 1
rightway = 3

right = 0
trees = 0
for elem in tree_map_list[::downway]:
    if elem[right % len(elem)] == '#':
        trees += 1
    right += rightway
print(trees)

# %%
def get_trees(rightway, downway):
    right = 0
    trees = 0
    for elem in tree_map_list[::downway]:
        if elem[right % len(elem)] == '#':
            trees += 1
        right += rightway
    return trees

# %%
total_trees_mult = 1
for right, down in [(1, 1), (3, 1), (5, 1), (7, 1), (1, 2)]:
    total_trees_mult *= get_trees(right, down)
print(total_trees_mult)

# %% [markdown]
# # Day 4

# %%
import re

# %%
required = ["byr", "iyr", "eyr", "hgt", "hcl", "ecl", "pid"]
optional = ["cid"]

# %%
with open("Day_4_list.txt") as f:
    passports = f.readlines()

# %%
clean_passports = []
new_dic = {}
for line in passports:
    if line != '\n':
        key_value = line.split(' ')
        for i, elem in enumerate(key_value):
            if i == len(key_value) -1:
                new_dic[elem.split(':')[0]] = elem.split(':')[1].replace('\n', '')
            else:
                new_dic[elem.split(':')[0]] = elem.split(':')[1]
    else:
        clean_passports.append(new_dic)
        new_dic = {}

clean_passports.append(new_dic)        
        
valid = 0
valid_passports = []
for passport in clean_passports:
    if set(passport) >= set(required):
        valid += 1
        valid_passports.append(passport)
print(valid)

# %%
counter = 0
for passport in valid_passports:
    try:
        if int(passport['byr']) >= 1920 and int(passport['byr']) <= 2002:
            if int(passport['iyr']) >= 2010 and int(passport['iyr']) <= 2020:
                if int(passport['eyr']) >= 2020 and int(passport['eyr']) <= 2030:
                    try:
                        height = int((passport['hgt'])[0:-2])
                        if (passport['hgt'][-2:] == 'cm' and height <= 193 and height >= 150) or (passport['hgt'][-2:] == 'in' and height <= 76 and height >= 59):                            
                            if passport['ecl'] in ["amb", "blu", "brn", "gry", "grn", "hzl", "oth"]:
                                if re.fullmatch(r"#+[0-9a-f]{6}", passport['hcl']):
                                    if len(passport['pid']) == 9:
                                        counter += 1
                                    
                    except:
                        print('Invalid height format')
                        
    except:
        print('Invalid data type')


print(counter)

# %% [markdown]
# # Day 5

# %%
with open("Day_5_list.txt", 'r') as f:
    seats = f.read()

# %%
seat_list = seats.split('\n')

# %%
parser = {
    "F" : 0,
    "B" : 1,
    "R" : 1,
    "L" : 0
}

# %%
def seat_parser(seat):
    row = 0
    column = 0
    for i, letter in enumerate(seat):
        if i <= 6:
            row += parser[letter] * 2**(6-i)
        else:
            column += parser[letter] * 2**(9-i)            
    return row, column

# %%
seat_numbers = [seat_parser(seat)[0]*8 + seat_parser(seat)[1] for seat in seat_list]

# %%
print(max(seat_numbers))

# %%
seat_numbers.sort()

# %%
neighbours = []
for i in range(1, len(seat_numbers) -1):
    if not(seat_numbers[i-1]+1 == seat_numbers[i] == seat_numbers[i+1]-1):
        neighbours.append(seat_numbers[i])

# %%
print(neighbours)

# %% [markdown]
# # Day 6

# %%
with open("Day_6_list.txt", 'r') as f:
    group_questions = f.read()

# %%
modified_questions = group_questions.split('\n\n')

# %%
counter = 0
for question in modified_questions:
    counter += len(set(question.replace('\n', '')))
print(counter)

# %%
counter = 0
for question in modified_questions:
    separated_questions = [set(ind_question) for ind_question in question.split('\n')]
    intersection_start = separated_questions[0]
    for ind_question in separated_questions:
        if ind_question != set():
            intersection_start = intersection_start.intersection(ind_question)
    counter += len(intersection_start)

print(counter)

# %% [markdown]
# # Day 7

# %%
with open('Day_7_list.txt', 'r') as f:
    bags = f.readlines()

# %%
bags_dic = {}
for bag in bags:
    key = bag.split('bags')[0][:-1]
    elems = bag.split('contain ')[1].replace('\n', '').replace('bags', '').replace('bag', '').replace('.', '')
    sub_dic = {}
    for elem in elems.split(', '):
        if elem != 'no other ':
            sub_dic[elem[2:-1]] = elem[0]
    bags_dic[key] = sub_dic

# %%
def get_outer_bags_length(input_bag, outer_bags):
    for key, value in bags_dic.items():
        if input_bag in value.keys():
            get_outer_bags_length(key, outer_bags)
            outer_bags.add(key)
    return len(outer_bags)

# %%
get_outer_bags_length('shiny gold', set())

# %%
def get_bags_amount(input_bag, amount):
    for key, value in bags_dic[input_bag].items():
        amount = amount + int(value) + int(value) * get_bags_amount(key, 0)
    return amount

# %%
get_bags_amount('shiny gold', 0)

# %% [markdown]
# # Day 8

# %%
with open('Day_8_list.txt', 'r') as f:
    instructions = f.readlines()

# %%
def get_last_acc(instructions):
    acc = 0
    i = 0
    is_infinite = False
    executed = []
    while True:
        if i >= len(instructions):
            break
        instruction = instructions[i].replace('\n', '')
        operation = instruction.split(' ')[0]
        value = int(instruction.split(' ')[1])
        if i in executed:
            is_infinite = True
            break
        executed.append(i)
        if operation == 'acc':
            acc += value
            i += 1
        elif operation == 'jmp':
            i += value
        else:
            i += 1
    return acc, is_infinite

# %%
get_last_acc(instructions)[0]

# %%
for i, instruction in enumerate(instructions):
    temp_list = instructions.copy()
    if instruction.startswith('jmp'):
        new_instruction = instruction.replace('jmp', 'nop')
        temp_list[i] = new_instruction
        if not get_last_acc(temp_list)[1]:
            print(get_last_acc(temp_list)[0])
            break
    elif instruction.startswith('nop'):
        new_instruction = instruction.replace('nop', 'jmp')
        temp_list[i] = new_instruction
        if not get_last_acc(temp_list)[1]:
            print(get_last_acc(temp_list)[0])
            break

# %% [markdown]
# # Day 9

# %%
with open("Day_9_list.txt", 'r') as f:
    xmas_code = f.read()

# %%
xmas_code_list = xmas_code.split('\n')

# %%
i = 0
for number in xmas_code_list[25+i:]:
    sums = []
    for j, prev_number_1 in enumerate(xmas_code_list[i:25+i]):
        for prev_number_2 in xmas_code_list[i+j:25+i]:
            sums.append(int(prev_number_1)+int(prev_number_2))
    i += 1
    if int(number) not in sums:
        print(number)
        break
# Out:
# 257342611

# %%
i = 0
searching = True
while searching:
    result = 0
    for j, number in enumerate(xmas_code_list[i:]):
        result += int(number)
        if result == 257342611:
            print(i, j)
            searching = False
            break
        if result > 257342611:
            break
    i += 1
# Out:
# 457 16

# %%
int_xmas = [int(value) for value in xmas_code_list[457:457+17]]

# %%
max(int_xmas) + min(int_xmas)
# Out:
# 35602097

# %% [markdown]
# # Day 10

# %%
with open('Day_10_list.txt', 'r') as f:
    adapters = f.read()

# %%
adapters_list = adapters.split('\n')

# %%
adapters_list = [int(adapter) for adapter in adapters_list if adapter != '']
adapters_list.append(0)
adapters_list.append(max(adapters_list)+3)

# %%
adapters_list.sort()

# %%
ones = 0
threes = 0
for i in range((len(adapters_list)-1)):
    if adapters_list[i+1] - adapters_list[i] == 1:
        ones += 1
    elif adapters_list[i+1] - adapters_list[i] == 3:
        threes += 1
print(ones*threes)
# Out:
# 1856

# %%
steps = {}
for i in range(0, len(adapters_list)-1):
    steps[adapters_list[i]] = []
    for j in range(1, 4):
        if adapters_list[i] + j == adapters_list[i + 1]:
            steps[adapters_list[i]].append(j)
        if i < len(adapters_list)-2 and adapters_list[i] + j == adapters_list[i + 2]:
            steps[adapters_list[i]].append(j)
        if i < len(adapters_list)-3 and adapters_list[i] + j == adapters_list[i + 3]:
            steps[adapters_list[i]].append(j)

# %%
options = []
prev_value = [1, 2, 3]
for value in steps.values():
    if [len(prev_value), len(value)] not in options:
        options.append([len(prev_value), len(value)])
    prev_value = value

# %%
options
# Out:
# [[3, 3], [3, 2], [2, 1], [1, 1], [1, 3], [1, 2]]

# %%
counter = 1
for step, values in steps.items():
    if len(values) == 3 and len(prev_values) == 1:
        counter *= 4
    if len(values) == 3 and len(prev_values) == 3:
        counter /= 4
        counter *= 7
    if len(values) == 2 and len(prev_values) == 1:
        counter *= 2
    prev_values = values.copy()

# %%
print(counter)
# Out:
# 2314037239808.0

# %% [markdown]
# # Day 11

# %%
with open("Day_11_list.txt", 'r') as f:
    seats = f.read()
seat_list = seats.split('\n')

# %%
seat_list.pop(-1)
# Out:
# ''

# %%
def get_adjacents(seat_list):
    new_seats = []
    for row_number, row in enumerate(seat_list):
        row_string = ''
        for position_number, position in enumerate(row):
            if position == '.':
                row_string += '.'
                continue            
            if row_number - 1 >= 0 and position_number - 1 >= 0:
                up_left = seat_list[row_number-1][position_number-1]
            else:
                up_left = '.'
            if row_number - 1 >= 0: 
                up = seat_list[row_number-1][position_number]
            else:
                up = '.'
            if row_number - 1 >= 0 and position_number + 1 < len(row):
                up_right = seat_list[row_number-1][position_number+1]
            else:
                up_right = '.'
            if position_number-1 >= 0:
                left = row[position_number-1]
            else:
                left = '.'
            if position_number + 1 < len(row):
                right = row[position_number+1]
            else:
                right = '.'
            if row_number + 1 < len(seat_list) and position_number - 1  >= 0:
                down_left = seat_list[row_number+1][position_number-1]
            else:
                down_left = '.'
            if row_number + 1 < len(seat_list): 
                down = seat_list[row_number+1][position_number]
            else:
                down = '.'
            if row_number + 1 < len(seat_list) and position_number + 1 < len(row):
                down_right = seat_list[row_number+1][position_number+1]
            else:
                down_right = '.'
            counter = 0
            for seat in [up_left, up, up_right, left, right, down_left, down, down_right]:
                if seat == '#':
                    counter += 1
            if counter >= 4 and position == '#':
                row_string += 'L'
            elif counter == 0 and position == 'L':
                row_string += '#'
            else:
                row_string += position
        new_seats.append(row_string)
    return new_seats

# %%
def count_final_occupieds(seat_list, function):
    old_seat_list = seat_list
    changes = True
    
    while changes:
        new_seat_list = function(old_seat_list)
        if new_seat_list == old_seat_list:
            changes = False
        old_seat_list = new_seat_list.copy()
        
    occupied = 0
    for row in new_seat_list:
        for char in row:
            if char == '#':
                occupied += 1
    return occupied

# %%
count_final_occupieds(seat_list, get_adjacents)
# Out:
# 2204

# %%
def find_adjacent_for_direction(seat_list, direction, row_number, position_number):
    i = 1
    while True:
        if (row_number + i * direction[0] >= 0) and (row_number + i * direction[0]) < len(seat_list):
            if (position_number + i * direction[1] >= 0) and (position_number + i * direction[1] < len(seat_list[row_number])):
                if seat_list[row_number + i * direction[0]][position_number + i * direction[1]] == '#':
                    return 1
                elif seat_list[row_number + i * direction[0]][position_number + i * direction[1]] == 'L':
                    return 0
                else:
                    i += 1
            else:
                return 0 
        else:
            return 0

# %%
def get_further_adjacents(seat_list):
    new_seats = []
    directions = {
    "up_left_direction" : (-1, -1),
    "up_direction" : (-1, 0),
    "up_right_direction" : (-1, 1),
    "left_direction" : (0, -1),
    "right_direction" : (0, 1),
    "down_left_direction" : (1, -1),
    "down_direction" : (1, 0),
    "down_right_direction" : (1, 1)
    }
    for row_number, row in enumerate(seat_list):
        row_string = ''
        for position_number, position in enumerate(row):
            if position == '.':
                row_string += '.'
                continue
            else:
                counter = 0
                for direction in directions.values():
                    counter += find_adjacent_for_direction(seat_list, direction, row_number, position_number)
                if counter >= 5 and position == '#':
                    row_string += 'L'
                elif counter == 0 and position == 'L':
                    row_string += '#'
                else:
                    row_string += position
                    
        new_seats.append(row_string)
                
    return new_seats

# %%
count_final_occupieds(seat_list, get_further_adjacents)
# Out:
# 1986

# %% [markdown]
# # Day 12

# %%
with open("Day_12_list.txt", 'r') as f:
    directions = f.read()

# %%
directions_list = directions.split('\n')

# %%
direction_mapping = {
    0: 'N',
    90: 'E',
    180: 'S',
    270: 'W'
}

progress = {
    'N' : 0,
    'E' : 0,
    'S' : 0,
    'W' : 0
}

directions = ['N', 'E', 'S', 'W']

current_direction = 90
for direction in directions_list:
    if direction[0] == 'F':
        progress[direction_mapping[current_direction]] += int(direction[1:])
    if direction[0] == 'R':
        current_direction = (current_direction + int(direction[1:])) % 360
    if direction[0] == 'L':
        current_direction = (current_direction - int(direction[1:])) % 360
    if direction[0] in directions:
        progress[direction[0]] += int(direction[1:])

# %%
result = abs(progress['S'] - progress['N']) + abs(progress['E'] - progress['W'])

# %%
result
# Out:
# 2057

# %%
# N, E, S, W

direction_mapping = {
    0: 'N',
    90: 'E',
    180: 'S',
    270: 'W'
}

degrees_mapping = {
    'N' : 0,
    'E' : 90,
    'S' : 180,
    'W' : 270
}

way_point = {
    'N' : 1,
    'E' : 10,
    'S' : 0,
    'W':  0
}

progress = {
    'N' : 0,
    'E' : 0,
    'S' : 0,
    'W' : 0
}

for direction in directions_list:
    if direction[0] == 'F':
        for key in way_point:
            progress[key] += way_point[key] * int(direction[1:])
    if direction[0] == 'R':
        temp_dic = way_point.copy()
        for key in way_point:
            temp_dic[key] = way_point[direction_mapping[(degrees_mapping[key] - int(direction[1:])) % 360]]
        way_point = temp_dic.copy()
    if direction[0] == 'L':
        temp_dic = way_point.copy()
        for key in way_point:
            temp_dic[key] = way_point[direction_mapping[(degrees_mapping[key] + int(direction[1:])) % 360]]
        way_point = temp_dic.copy()
    if direction[0] in directions:
        way_point[direction[0]] += int(direction[1:])
# Out:
# Direction: E2
# Way point: {'N': 1, 'E': 12, 'S': 0, 'W': 0}
# Progress: {'N': 0, 'E': 0, 'S': 0, 'W': 0}
# Direction: F24
# Way point: {'N': 1, 'E': 12, 'S': 0, 'W': 0}
# Progress: {'N': 24, 'E': 288, 'S': 0, 'W': 0}
# Direction: F60
# Way point: {'N': 1, 'E': 12, 'S': 0, 'W': 0}
# Progress: {'N': 84, 'E': 1008, 'S': 0, 'W': 0}
# Direction: N3
# Way point: {'N': 4, 'E': 12, 'S': 0, 'W': 0}
# Progress: {'N': 84, 'E': 1008, 'S': 0, 'W': 0}
# Direction: E1
# Way point: {'N': 4, 'E': 13, 'S': 0, 'W': 0}
# Progress: {'N': 84, 'E': 1008, 'S': 0, 'W': 0}
# Direction: R180
# Way point: {'N': 0, 'E': 0, 'S': 4, 'W': 13}
# Progress: {'N': 84, 'E': 1008, 'S': 0, 'W': 0}
# Direction: F14
# Way point: {'N': 0, 'E': 0, 'S': 4, 'W': 13}
# Progress: {'N': 84, 'E': 1008, 'S': 56, 'W': 182}
# Direction: L90
# Way point: {'N': 0, 'E': 4, 'S': 13, 'W': 0}
# Progress: {'N': 84, 'E': 1008, 'S': 56, 'W': 182}
# Direction: N4
# Way point: {'N': 4, 'E': 4, 'S': 13, 'W': 0}
# Progress: {'N': 84, 'E': 1008, 'S': 56, 'W': 182}
# Direction: W3
# Way point: {'N': 4, 'E': 4, 'S': 13, 'W': 3}
# Progress: {'N': 84, 'E': 1008, 'S': 56, 'W': 182}
# Direction: F81
# Way point: {'N': 4, 'E': 4, 'S': 13, 'W': 3}
# Progress: {'N': 408, 'E': 1332, 'S': 1109, 'W': 425}
# Direction: R90
# Way point: {'N': 3, 'E': 4, 'S': 4, 'W': 13}
# Progress: {'N': 408, 'E': 1332, 'S': 1109, 'W': 425}
# Direction: F43
# Way point: {'N': 3, 'E': 4, 'S': 4, 'W': 13}
# Progress: {'N': 537, 'E': 1504, 'S': 1281, 'W': 984}
# Direction: R90
# Way point: {'N': 13, 'E': 3, 'S': 4, 'W': 4}
# Progress: {'N': 537, 'E': 1504, 'S': 1281, 'W': 984}
# Direction: F40
# Way point: {'N': 13, 'E': 3, 'S': 4, 'W': 4}
# Progress: {'N': 1057, 'E': 1624, 'S': 1441, 'W': 1144}
# Direction: S2
# Way point: {'N': 13, 'E': 3, 'S': 6, 'W': 4}
# Progress: {'N': 1057, 'E': 1624, 'S': 1441, 'W': 1144}
# Direction: F56
# Way point: {'N': 13, 'E': 3, 'S': 6, 'W': 4}
# Progress: {'N': 1785, 'E': 1792, 'S': 1777, 'W': 1368}
# Direction: L90
# Way point: {'N': 3, 'E': 6, 'S': 4, 'W': 13}
# Progress: {'N': 1785, 'E': 1792, 'S': 1777, 'W': 1368}
# Direction: E1
# Way point: {'N': 3, 'E': 7, 'S': 4, 'W': 13}
# Progress: {'N': 1785, 'E': 1792, 'S': 1777, 'W': 1368}
# Direction: S1
# Way point: {'N': 3, 'E': 7, 'S': 5, 'W': 13}
# Progress: {'N': 1785, 'E': 1792, 'S': 1777, 'W': 1368}
# Direction: R90
# Way point: {'N': 13, 'E': 3, 'S': 7, 'W': 5}
# Progress: {'N': 1785, 'E': 1792, 'S': 1777, 'W': 1368}
# Direction: F66
# Way point: {'N': 13, 'E': 3, 'S': 7, 'W': 5}
# Progress: {'N': 2643, 'E': 1990, 'S': 2239, 'W': 1698}
# Direction: L180
# Way point: {'N': 7, 'E': 5, 'S': 13, 'W': 3}
# Progress: {'N': 2643, 'E': 1990, 'S': 2239, 'W': 1698}
# Direction: W2
# Way point: {'N': 7, 'E': 5, 'S': 13, 'W': 5}
# Progress: {'N': 2643, 'E': 1990, 'S': 2239, 'W': 1698}
# Direction: F84
# Way point: {'N': 7, 'E': 5, 'S': 13, 'W': 5}
# Progress: {'N': 3231, 'E': 2410, 'S': 3331, 'W': 2118}
# Direction: R90
# Way point: {'N': 5, 'E': 7, 'S': 5, 'W': 13}
# Progress: {'N': 3231, 'E': 2410, 'S': 3331, 'W': 2118}
# Direction: E4
# Way point: {'N': 5, 'E': 11, 'S': 5, 'W': 13}
# Progress: {'N': 3231, 'E': 2410, 'S': 3331, 'W': 2118}
# Direction: F32
# Way point: {'N': 5, 'E': 11, 'S': 5, 'W': 13}
# Progress: {'N': 3391, 'E': 2762, 'S': 3491, 'W': 2534}
# Direction: E5
# Way point: {'N': 5, 'E': 16, 'S': 5, 'W': 13}
# Progress: {'N': 3391, 'E': 2762, 'S': 3491, 'W': 2534}
# Direction: R90
# Way point: {'N': 13, 'E': 5, 'S': 16, 'W': 5}
# Progress: {'N': 3391, 'E': 2762, 'S': 3491, 'W': 2534}
# Direction: F44
# Way point: {'N': 13, 'E': 5, 'S': 16, 'W': 5}
# Progress: {'N': 3963, 'E': 2982, 'S': 4195, 'W': 2754}
# Direction: E1
# Way point: {'N': 13, 'E': 6, 'S': 16, 'W': 5}
# Progress: {'N': 3963, 'E': 2982, 'S': 4195, 'W': 2754}
# Direction: R90
# Way point: {'N': 5, 'E': 13, 'S': 6, 'W': 16}
# Progress: {'N': 3963, 'E': 2982, 'S': 4195, 'W': 2754}
# Direction: E4
# Way point: {'N': 5, 'E': 17, 'S': 6, 'W': 16}
# Progress: {'N': 3963, 'E': 2982, 'S': 4195, 'W': 2754}
# Direction: L90
# Way point: {'N': 17, 'E': 6, 'S': 16, 'W': 5}
# Progress: {'N': 3963, 'E': 2982, 'S': 4195, 'W': 2754}
# Direction: N1
# Way point: {'N': 18, 'E': 6, 'S': 16, 'W': 5}
# Progress: {'N': 3963, 'E': 2982, 'S': 4195, 'W': 2754}
# Direction: W2
# Way point: {'N': 18, 'E': 6, 'S': 16, 'W': 7}
# Progress: {'N': 3963, 'E': 2982, 'S': 4195, 'W': 2754}
# Direction: R90
# Way point: {'N': 7, 'E': 18, 'S': 6, 'W': 16}
# Progress: {'N': 3963, 'E': 2982, 'S': 4195, 'W': 2754}
# Direction: E5
# Way point: {'N': 7, 'E': 23, 'S': 6, 'W': 16}
# Progress: {'N': 3963, 'E': 2982, 'S': 4195, 'W': 2754}
# Direction: L90
# Way point: {'N': 23, 'E': 6, 'S': 16, 'W': 7}
# Progress: {'N': 3963, 'E': 2982, 'S': 4195, 'W': 2754}
# Direction: F86
# Way point: {'N': 23, 'E': 6, 'S': 16, 'W': 7}
# Progress: {'N': 5941, 'E': 3498, 'S': 5571, 'W': 3356}
# Direction: L180
# Way point: {'N': 16, 'E': 7, 'S': 23, 'W': 6}
# Progress: {'N': 5941, 'E': 3498, 'S': 5571, 'W': 3356}
# Direction: S2
# Way point: {'N': 16, 'E': 7, 'S': 25, 'W': 6}
# Progress: {'N': 5941, 'E': 3498, 'S': 5571, 'W': 3356}
# Direction: R180
# Way point: {'N': 25, 'E': 6, 'S': 16, 'W': 7}
# Progress: {'N': 5941, 'E': 3498, 'S': 5571, 'W': 3356}
# Direction: E2
# Way point: {'N': 25, 'E': 8, 'S': 16, 'W': 7}
# Progress: {'N': 5941, 'E': 3498, 'S': 5571, 'W': 3356}
# Direction: F22
# Way point: {'N': 25, 'E': 8, 'S': 16, 'W': 7}
# Progress: {'N': 6491, 'E': 3674, 'S': 5923, 'W': 3510}
# Direction: R180
# Way point: {'N': 16, 'E': 7, 'S': 25, 'W': 8}
# Progress: {'N': 6491, 'E': 3674, 'S': 5923, 'W': 3510}
# Direction: F42
# Way point: {'N': 16, 'E': 7, 'S': 25, 'W': 8}
# Progress: {'N': 7163, 'E': 3968, 'S': 6973, 'W': 3846}
# Direction: L180
# Way point: {'N': 25, 'E': 8, 'S': 16, 'W': 7}
# Progress: {'N': 7163, 'E': 3968, 'S': 6973, 'W': 3846}
# Direction: S4
# Way point: {'N': 25, 'E': 8, 'S': 20, 'W': 7}
# Progress: {'N': 7163, 'E': 3968, 'S': 6973, 'W': 3846}
# Direction: W4
# Way point: {'N': 25, 'E': 8, 'S': 20, 'W': 11}
# Progress: {'N': 7163, 'E': 3968, 'S': 6973, 'W': 3846}
# Direction: N5
# Way point: {'N': 30, 'E': 8, 'S': 20, 'W': 11}
# Progress: {'N': 7163, 'E': 3968, 'S': 6973, 'W': 3846}
# Direction: R270
# Way point: {'N': 8, 'E': 20, 'S': 11, 'W': 30}
# Progress: {'N': 7163, 'E': 3968, 'S': 6973, 'W': 3846}
# Direction: F23
# Way point: {'N': 8, 'E': 20, 'S': 11, 'W': 30}
# Progress: {'N': 7347, 'E': 4428, 'S': 7226, 'W': 4536}
# Direction: N3
# Way point: {'N': 11, 'E': 20, 'S': 11, 'W': 30}
# Progress: {'N': 7347, 'E': 4428, 'S': 7226, 'W': 4536}
# Direction: F18
# Way point: {'N': 11, 'E': 20, 'S': 11, 'W': 30}
# Progress: {'N': 7545, 'E': 4788, 'S': 7424, 'W': 5076}
# Direction: E2
# Way point: {'N': 11, 'E': 22, 'S': 11, 'W': 30}
# Progress: {'N': 7545, 'E': 4788, 'S': 7424, 'W': 5076}
# Direction: N2
# Way point: {'N': 13, 'E': 22, 'S': 11, 'W': 30}
# Progress: {'N': 7545, 'E': 4788, 'S': 7424, 'W': 5076}
# Direction: S3
# Way point: {'N': 13, 'E': 22, 'S': 14, 'W': 30}
# Progress: {'N': 7545, 'E': 4788, 'S': 7424, 'W': 5076}
# Direction: W5
# Way point: {'N': 13, 'E': 22, 'S': 14, 'W': 35}
# Progress: {'N': 7545, 'E': 4788, 'S': 7424, 'W': 5076}
# Direction: R90
# Way point: {'N': 35, 'E': 13, 'S': 22, 'W': 14}
# Progress: {'N': 7545, 'E': 4788, 'S': 7424, 'W': 5076}
# Direction: E4
# Way point: {'N': 35, 'E': 17, 'S': 22, 'W': 14}
# Progress: {'N': 7545, 'E': 4788, 'S': 7424, 'W': 5076}
# Direction: S1
# Way point: {'N': 35, 'E': 17, 'S': 23, 'W': 14}
# Progress: {'N': 7545, 'E': 4788, 'S': 7424, 'W': 5076}
# Direction: R180
# Way point: {'N': 23, 'E': 14, 'S': 35, 'W': 17}
# Progress: {'N': 7545, 'E': 4788, 'S': 7424, 'W': 5076}
# Direction: S1
# Way point: {'N': 23, 'E': 14, 'S': 36, 'W': 17}
# Progress: {'N': 7545, 'E': 4788, 'S': 7424, 'W': 5076}
# Direction: F69
# Way point: {'N': 23, 'E': 14, 'S': 36, 'W': 17}
# Progress: {'N': 9132, 'E': 5754, 'S': 9908, 'W': 6249}
# Direction: W2
# Way point: {'N': 23, 'E': 14, 'S': 36, 'W': 19}
# Progress: {'N': 9132, 'E': 5754, 'S': 9908, 'W': 6249}
# Direction: F55
# Way point: {'N': 23, 'E': 14, 'S': 36, 'W': 19}
# Progress: {'N': 10397, 'E': 6524, 'S': 11888, 'W': 7294}
# Direction: E5
# Way point: {'N': 23, 'E': 19, 'S': 36, 'W': 19}
# Progress: {'N': 10397, 'E': 6524, 'S': 11888, 'W': 7294}
# Direction: S3
# Way point: {'N': 23, 'E': 19, 'S': 39, 'W': 19}
# Progress: {'N': 10397, 'E': 6524, 'S': 11888, 'W': 7294}
# Direction: E4
# Way point: {'N': 23, 'E': 23, 'S': 39, 'W': 19}
# Progress: {'N': 10397, 'E': 6524, 'S': 11888, 'W': 7294}
# Direction: N1
# Way point: {'N': 24, 'E': 23, 'S': 39, 'W': 19}
# Progress: {'N': 10397, 'E': 6524, 'S': 11888, 'W': 7294}
# Direction: R180
# Way point: {'N': 39, 'E': 19, 'S': 24, 'W': 23}
# Progress: {'N': 10397, 'E': 6524, 'S': 11888, 'W': 7294}
# Direction: E1
# Way point: {'N': 39, 'E': 20, 'S': 24, 'W': 23}
# Progress: {'N': 10397, 'E': 6524, 'S': 11888, 'W': 7294}
# Direction: S5
# Way point: {'N': 39, 'E': 20, 'S': 29, 'W': 23}
# Progress: {'N': 10397, 'E': 6524, 'S': 11888, 'W': 7294}
# Direction: W1
# Way point: {'N': 39, 'E': 20, 'S': 29, 'W': 24}
# Progress: {'N': 10397, 'E': 6524, 'S': 11888, 'W': 7294}
# Direction: S5
# Way point: {'N': 39, 'E': 20, 'S': 34, 'W': 24}
# Progress: {'N': 10397, 'E': 6524, 'S': 11888, 'W': 7294}
# Direction: L270
# Way point: {'N': 24, 'E': 39, 'S': 20, 'W': 34}
# Progress: {'N': 10397, 'E': 6524, 'S': 11888, 'W': 7294}
# Direction: F17
# Way point: {'N': 24, 'E': 39, 'S': 20, 'W': 34}
# Progress: {'N': 10805, 'E': 7187, 'S': 12228, 'W': 7872}
# Direction: R180
# Way point: {'N': 20, 'E': 34, 'S': 24, 'W': 39}
# Progress: {'N': 10805, 'E': 7187, 'S': 12228, 'W': 7872}
# Direction: N5
# Way point: {'N': 25, 'E': 34, 'S': 24, 'W': 39}
# Progress: {'N': 10805, 'E': 7187, 'S': 12228, 'W': 7872}
# Direction: F6
# Way point: {'N': 25, 'E': 34, 'S': 24, 'W': 39}
# Progress: {'N': 10955, 'E': 7391, 'S': 12372, 'W': 8106}
# Direction: S3
# Way point: {'N': 25, 'E': 34, 'S': 27, 'W': 39}
# Progress: {'N': 10955, 'E': 7391, 'S': 12372, 'W': 8106}
# Direction: R180
# Way point: {'N': 27, 'E': 39, 'S': 25, 'W': 34}
# Progress: {'N': 10955, 'E': 7391, 'S': 12372, 'W': 8106}
# Direction: F75
# Way point: {'N': 27, 'E': 39, 'S': 25, 'W': 34}
# Progress: {'N': 12980, 'E': 10316, 'S': 14247, 'W': 10656}
# Direction: S3
# Way point: {'N': 27, 'E': 39, 'S': 28, 'W': 34}
# Progress: {'N': 12980, 'E': 10316, 'S': 14247, 'W': 10656}
# Direction: F90
# Way point: {'N': 27, 'E': 39, 'S': 28, 'W': 34}
# Progress: {'N': 15410, 'E': 13826, 'S': 16767, 'W': 13716}
# Direction: W3
# Way point: {'N': 27, 'E': 39, 'S': 28, 'W': 37}
# Progress: {'N': 15410, 'E': 13826, 'S': 16767, 'W': 13716}
# Direction: F98
# Way point: {'N': 27, 'E': 39, 'S': 28, 'W': 37}
# Progress: {'N': 18056, 'E': 17648, 'S': 19511, 'W': 17342}
# Direction: N2
# Way point: {'N': 29, 'E': 39, 'S': 28, 'W': 37}
# Progress: {'N': 18056, 'E': 17648, 'S': 19511, 'W': 17342}
# Direction: F54
# Way point: {'N': 29, 'E': 39, 'S': 28, 'W': 37}
# Progress: {'N': 19622, 'E': 19754, 'S': 21023, 'W': 19340}
# Direction: E5
# Way point: {'N': 29, 'E': 44, 'S': 28, 'W': 37}
# Progress: {'N': 19622, 'E': 19754, 'S': 21023, 'W': 19340}
# Direction: S5
# Way point: {'N': 29, 'E': 44, 'S': 33, 'W': 37}
# Progress: {'N': 19622, 'E': 19754, 'S': 21023, 'W': 19340}
# Direction: F4
# Way point: {'N': 29, 'E': 44, 'S': 33, 'W': 37}
# Progress: {'N': 19738, 'E': 19930, 'S': 21155, 'W': 19488}
# Direction: E5
# Way point: {'N': 29, 'E': 49, 'S': 33, 'W': 37}
# Progress: {'N': 19738, 'E': 19930, 'S': 21155, 'W': 19488}
# Direction: R90
# Way point: {'N': 37, 'E': 29, 'S': 49, 'W': 33}
# Progress: {'N': 19738, 'E': 19930, 'S': 21155, 'W': 19488}
# Direction: N4
# Way point: {'N': 41, 'E': 29, 'S': 49, 'W': 33}
# Progress: {'N': 19738, 'E': 19930, 'S': 21155, 'W': 19488}
# Direction: L90
# Way point: {'N': 29, 'E': 49, 'S': 33, 'W': 41}
# Progress: {'N': 19738, 'E': 19930, 'S': 21155, 'W': 19488}
# Direction: E4
# Way point: {'N': 29, 'E': 53, 'S': 33, 'W': 41}
# Progress: {'N': 19738, 'E': 19930, 'S': 21155, 'W': 19488}
# Direction: N3
# Way point: {'N': 32, 'E': 53, 'S': 33, 'W': 41}
# Progress: {'N': 19738, 'E': 19930, 'S': 21155, 'W': 19488}
# Direction: F75
# Way point: {'N': 32, 'E': 53, 'S': 33, 'W': 41}
# Progress: {'N': 22138, 'E': 23905, 'S': 23630, 'W': 22563}
# Direction: E3
# Way point: {'N': 32, 'E': 56, 'S': 33, 'W': 41}
# Progress: {'N': 22138, 'E': 23905, 'S': 23630, 'W': 22563}
# Direction: S2
# Way point: {'N': 32, 'E': 56, 'S': 35, 'W': 41}
# Progress: {'N': 22138, 'E': 23905, 'S': 23630, 'W': 22563}
# Direction: F89
# Way point: {'N': 32, 'E': 56, 'S': 35, 'W': 41}
# Progress: {'N': 24986, 'E': 28889, 'S': 26745, 'W': 26212}
# Direction: E1
# Way point: {'N': 32, 'E': 57, 'S': 35, 'W': 41}
# Progress: {'N': 24986, 'E': 28889, 'S': 26745, 'W': 26212}
# Direction: R180
# Way point: {'N': 35, 'E': 41, 'S': 32, 'W': 57}
# Progress: {'N': 24986, 'E': 28889, 'S': 26745, 'W': 26212}
# Direction: S3
# Way point: {'N': 35, 'E': 41, 'S': 35, 'W': 57}
# Progress: {'N': 24986, 'E': 28889, 'S': 26745, 'W': 26212}
# Direction: E2
# Way point: {'N': 35, 'E': 43, 'S': 35, 'W': 57}
# Progress: {'N': 24986, 'E': 28889, 'S': 26745, 'W': 26212}
# Direction: R270
# Way point: {'N': 43, 'E': 35, 'S': 57, 'W': 35}
# Progress: {'N': 24986, 'E': 28889, 'S': 26745, 'W': 26212}
# Direction: W4
# Way point: {'N': 43, 'E': 35, 'S': 57, 'W': 39}
# Progress: {'N': 24986, 'E': 28889, 'S': 26745, 'W': 26212}
# Direction: L90
# Way point: {'N': 35, 'E': 57, 'S': 39, 'W': 43}
# Progress: {'N': 24986, 'E': 28889, 'S': 26745, 'W': 26212}
# Direction: N5
# Way point: {'N': 40, 'E': 57, 'S': 39, 'W': 43}
# Progress: {'N': 24986, 'E': 28889, 'S': 26745, 'W': 26212}
# Direction: E4
# Way point: {'N': 40, 'E': 61, 'S': 39, 'W': 43}
# Progress: {'N': 24986, 'E': 28889, 'S': 26745, 'W': 26212}
# Direction: W3
# Way point: {'N': 40, 'E': 61, 'S': 39, 'W': 46}
# Progress: {'N': 24986, 'E': 28889, 'S': 26745, 'W': 26212}
# Direction: N1
# Way point: {'N': 41, 'E': 61, 'S': 39, 'W': 46}
# Progress: {'N': 24986, 'E': 28889, 'S': 26745, 'W': 26212}
# Direction: F37
# Way point: {'N': 41, 'E': 61, 'S': 39, 'W': 46}
# Progress: {'N': 26503, 'E': 31146, 'S': 28188, 'W': 27914}
# Direction: L90
# Way point: {'N': 61, 'E': 39, 'S': 46, 'W': 41}
# Progress: {'N': 26503, 'E': 31146, 'S': 28188, 'W': 27914}
# Direction: N5
# Way point: {'N': 66, 'E': 39, 'S': 46, 'W': 41}
# Progress: {'N': 26503, 'E': 31146, 'S': 28188, 'W': 27914}
# Direction: E3
# Way point: {'N': 66, 'E': 42, 'S': 46, 'W': 41}
# Progress: {'N': 26503, 'E': 31146, 'S': 28188, 'W': 27914}
# Direction: N3
# Way point: {'N': 69, 'E': 42, 'S': 46, 'W': 41}
# Progress: {'N': 26503, 'E': 31146, 'S': 28188, 'W': 27914}
# Direction: L90
# Way point: {'N': 42, 'E': 46, 'S': 41, 'W': 69}
# Progress: {'N': 26503, 'E': 31146, 'S': 28188, 'W': 27914}
# Direction: W1
# Way point: {'N': 42, 'E': 46, 'S': 41, 'W': 70}
# Progress: {'N': 26503, 'E': 31146, 'S': 28188, 'W': 27914}
# Direction: R90
# Way point: {'N': 70, 'E': 42, 'S': 46, 'W': 41}
# Progress: {'N': 26503, 'E': 31146, 'S': 28188, 'W': 27914}
# Direction: F25
# Way point: {'N': 70, 'E': 42, 'S': 46, 'W': 41}
# Progress: {'N': 28253, 'E': 32196, 'S': 29338, 'W': 28939}
# Direction: N2
# Way point: {'N': 72, 'E': 42, 'S': 46, 'W': 41}
# Progress: {'N': 28253, 'E': 32196, 'S': 29338, 'W': 28939}
# Direction: R90
# Way point: {'N': 41, 'E': 72, 'S': 42, 'W': 46}
# Progress: {'N': 28253, 'E': 32196, 'S': 29338, 'W': 28939}
# Direction: E4
# Way point: {'N': 41, 'E': 76, 'S': 42, 'W': 46}
# Progress: {'N': 28253, 'E': 32196, 'S': 29338, 'W': 28939}
# Direction: F81
# Way point: {'N': 41, 'E': 76, 'S': 42, 'W': 46}
# Progress: {'N': 31574, 'E': 38352, 'S': 32740, 'W': 32665}
# Direction: N5
# Way point: {'N': 46, 'E': 76, 'S': 42, 'W': 46}
# Progress: {'N': 31574, 'E': 38352, 'S': 32740, 'W': 32665}
# Direction: L90
# Way point: {'N': 76, 'E': 42, 'S': 46, 'W': 46}
# Progress: {'N': 31574, 'E': 38352, 'S': 32740, 'W': 32665}
# Direction: F47
# Way point: {'N': 76, 'E': 42, 'S': 46, 'W': 46}
# Progress: {'N': 35146, 'E': 40326, 'S': 34902, 'W': 34827}
# Direction: E1
# Way point: {'N': 76, 'E': 43, 'S': 46, 'W': 46}
# Progress: {'N': 35146, 'E': 40326, 'S': 34902, 'W': 34827}
# Direction: F86
# Way point: {'N': 76, 'E': 43, 'S': 46, 'W': 46}
# Progress: {'N': 41682, 'E': 44024, 'S': 38858, 'W': 38783}
# Direction: N5
# Way point: {'N': 81, 'E': 43, 'S': 46, 'W': 46}
# Progress: {'N': 41682, 'E': 44024, 'S': 38858, 'W': 38783}
# Direction: W1
# Way point: {'N': 81, 'E': 43, 'S': 46, 'W': 47}
# Progress: {'N': 41682, 'E': 44024, 'S': 38858, 'W': 38783}
# Direction: N2
# Way point: {'N': 83, 'E': 43, 'S': 46, 'W': 47}
# Progress: {'N': 41682, 'E': 44024, 'S': 38858, 'W': 38783}
# Direction: F35
# Way point: {'N': 83, 'E': 43, 'S': 46, 'W': 47}
# Progress: {'N': 44587, 'E': 45529, 'S': 40468, 'W': 40428}
# Direction: L90
# Way point: {'N': 43, 'E': 46, 'S': 47, 'W': 83}
# Progress: {'N': 44587, 'E': 45529, 'S': 40468, 'W': 40428}
# Direction: W4
# Way point: {'N': 43, 'E': 46, 'S': 47, 'W': 87}
# Progress: {'N': 44587, 'E': 45529, 'S': 40468, 'W': 40428}
# Direction: F35
# Way point: {'N': 43, 'E': 46, 'S': 47, 'W': 87}
# Progress: {'N': 46092, 'E': 47139, 'S': 42113, 'W': 43473}
# Direction: R90
# Way point: {'N': 87, 'E': 43, 'S': 46, 'W': 47}
# Progress: {'N': 46092, 'E': 47139, 'S': 42113, 'W': 43473}
# Direction: W3
# Way point: {'N': 87, 'E': 43, 'S': 46, 'W': 50}
# Progress: {'N': 46092, 'E': 47139, 'S': 42113, 'W': 43473}
# Direction: S3
# Way point: {'N': 87, 'E': 43, 'S': 49, 'W': 50}
# Progress: {'N': 46092, 'E': 47139, 'S': 42113, 'W': 43473}
# Direction: W1
# Way point: {'N': 87, 'E': 43, 'S': 49, 'W': 51}
# Progress: {'N': 46092, 'E': 47139, 'S': 42113, 'W': 43473}
# Direction: S3
# Way point: {'N': 87, 'E': 43, 'S': 52, 'W': 51}
# Progress: {'N': 46092, 'E': 47139, 'S': 42113, 'W': 43473}
# Direction: E5
# Way point: {'N': 87, 'E': 48, 'S': 52, 'W': 51}
# Progress: {'N': 46092, 'E': 47139, 'S': 42113, 'W': 43473}
# Direction: L180
# Way point: {'N': 52, 'E': 51, 'S': 87, 'W': 48}
# Progress: {'N': 46092, 'E': 47139, 'S': 42113, 'W': 43473}
# Direction: F1
# Way point: {'N': 52, 'E': 51, 'S': 87, 'W': 48}
# Progress: {'N': 46144, 'E': 47190, 'S': 42200, 'W': 43521}
# Direction: L90
# Way point: {'N': 51, 'E': 87, 'S': 48, 'W': 52}
# Progress: {'N': 46144, 'E': 47190, 'S': 42200, 'W': 43521}
# Direction: E4
# Way point: {'N': 51, 'E': 91, 'S': 48, 'W': 52}
# Progress: {'N': 46144, 'E': 47190, 'S': 42200, 'W': 43521}
# Direction: L90
# Way point: {'N': 91, 'E': 48, 'S': 52, 'W': 51}
# Progress: {'N': 46144, 'E': 47190, 'S': 42200, 'W': 43521}
# Direction: S4
# Way point: {'N': 91, 'E': 48, 'S': 56, 'W': 51}
# Progress: {'N': 46144, 'E': 47190, 'S': 42200, 'W': 43521}
# Direction: F58
# Way point: {'N': 91, 'E': 48, 'S': 56, 'W': 51}
# Progress: {'N': 51422, 'E': 49974, 'S': 45448, 'W': 46479}
# Direction: N2
# Way point: {'N': 93, 'E': 48, 'S': 56, 'W': 51}
# Progress: {'N': 51422, 'E': 49974, 'S': 45448, 'W': 46479}
# Direction: F95
# Way point: {'N': 93, 'E': 48, 'S': 56, 'W': 51}
# Progress: {'N': 60257, 'E': 54534, 'S': 50768, 'W': 51324}
# Direction: L180
# Way point: {'N': 56, 'E': 51, 'S': 93, 'W': 48}
# Progress: {'N': 60257, 'E': 54534, 'S': 50768, 'W': 51324}
# Direction: F27
# Way point: {'N': 56, 'E': 51, 'S': 93, 'W': 48}
# Progress: {'N': 61769, 'E': 55911, 'S': 53279, 'W': 52620}
# Direction: S4
# Way point: {'N': 56, 'E': 51, 'S': 97, 'W': 48}
# Progress: {'N': 61769, 'E': 55911, 'S': 53279, 'W': 52620}
# Direction: L90
# Way point: {'N': 51, 'E': 97, 'S': 48, 'W': 56}
# Progress: {'N': 61769, 'E': 55911, 'S': 53279, 'W': 52620}
# Direction: E4
# Way point: {'N': 51, 'E': 101, 'S': 48, 'W': 56}
# Progress: {'N': 61769, 'E': 55911, 'S': 53279, 'W': 52620}
# Direction: F90
# Way point: {'N': 51, 'E': 101, 'S': 48, 'W': 56}
# Progress: {'N': 66359, 'E': 65001, 'S': 57599, 'W': 57660}
# Direction: E5
# Way point: {'N': 51, 'E': 106, 'S': 48, 'W': 56}
# Progress: {'N': 66359, 'E': 65001, 'S': 57599, 'W': 57660}
# Direction: N2
# Way point: {'N': 53, 'E': 106, 'S': 48, 'W': 56}
# Progress: {'N': 66359, 'E': 65001, 'S': 57599, 'W': 57660}
# Direction: F36
# Way point: {'N': 53, 'E': 106, 'S': 48, 'W': 56}
# Progress: {'N': 68267, 'E': 68817, 'S': 59327, 'W': 59676}
# Direction: W2
# Way point: {'N': 53, 'E': 106, 'S': 48, 'W': 58}
# Progress: {'N': 68267, 'E': 68817, 'S': 59327, 'W': 59676}
# Direction: S5
# Way point: {'N': 53, 'E': 106, 'S': 53, 'W': 58}
# Progress: {'N': 68267, 'E': 68817, 'S': 59327, 'W': 59676}
# Direction: N3
# Way point: {'N': 56, 'E': 106, 'S': 53, 'W': 58}
# Progress: {'N': 68267, 'E': 68817, 'S': 59327, 'W': 59676}
# Direction: W4
# Way point: {'N': 56, 'E': 106, 'S': 53, 'W': 62}
# Progress: {'N': 68267, 'E': 68817, 'S': 59327, 'W': 59676}
# Direction: S1
# Way point: {'N': 56, 'E': 106, 'S': 54, 'W': 62}
# Progress: {'N': 68267, 'E': 68817, 'S': 59327, 'W': 59676}
# Direction: F58
# Way point: {'N': 56, 'E': 106, 'S': 54, 'W': 62}
# Progress: {'N': 71515, 'E': 74965, 'S': 62459, 'W': 63272}
# Direction: E4
# Way point: {'N': 56, 'E': 110, 'S': 54, 'W': 62}
# Progress: {'N': 71515, 'E': 74965, 'S': 62459, 'W': 63272}
# Direction: R90
# Way point: {'N': 62, 'E': 56, 'S': 110, 'W': 54}
# Progress: {'N': 71515, 'E': 74965, 'S': 62459, 'W': 63272}
# Direction: F60
# Way point: {'N': 62, 'E': 56, 'S': 110, 'W': 54}
# Progress: {'N': 75235, 'E': 78325, 'S': 69059, 'W': 66512}
# Direction: E1
# Way point: {'N': 62, 'E': 57, 'S': 110, 'W': 54}
# Progress: {'N': 75235, 'E': 78325, 'S': 69059, 'W': 66512}
# Direction: N2
# Way point: {'N': 64, 'E': 57, 'S': 110, 'W': 54}
# Progress: {'N': 75235, 'E': 78325, 'S': 69059, 'W': 66512}
# Direction: R90
# Way point: {'N': 54, 'E': 64, 'S': 57, 'W': 110}
# Progress: {'N': 75235, 'E': 78325, 'S': 69059, 'W': 66512}
# Direction: N1
# Way point: {'N': 55, 'E': 64, 'S': 57, 'W': 110}
# Progress: {'N': 75235, 'E': 78325, 'S': 69059, 'W': 66512}
# Direction: W2
# Way point: {'N': 55, 'E': 64, 'S': 57, 'W': 112}
# Progress: {'N': 75235, 'E': 78325, 'S': 69059, 'W': 66512}
# Direction: L90
# Way point: {'N': 64, 'E': 57, 'S': 112, 'W': 55}
# Progress: {'N': 75235, 'E': 78325, 'S': 69059, 'W': 66512}
# Direction: N3
# Way point: {'N': 67, 'E': 57, 'S': 112, 'W': 55}
# Progress: {'N': 75235, 'E': 78325, 'S': 69059, 'W': 66512}
# Direction: F16
# Way point: {'N': 67, 'E': 57, 'S': 112, 'W': 55}
# Progress: {'N': 76307, 'E': 79237, 'S': 70851, 'W': 67392}
# Direction: S2
# Way point: {'N': 67, 'E': 57, 'S': 114, 'W': 55}
# Progress: {'N': 76307, 'E': 79237, 'S': 70851, 'W': 67392}
# Direction: R90
# Way point: {'N': 55, 'E': 67, 'S': 57, 'W': 114}
# Progress: {'N': 76307, 'E': 79237, 'S': 70851, 'W': 67392}
# Direction: F3
# Way point: {'N': 55, 'E': 67, 'S': 57, 'W': 114}
# Progress: {'N': 76472, 'E': 79438, 'S': 71022, 'W': 67734}
# Direction: R270
# Way point: {'N': 67, 'E': 57, 'S': 114, 'W': 55}
# Progress: {'N': 76472, 'E': 79438, 'S': 71022, 'W': 67734}
# Direction: F98
# Way point: {'N': 67, 'E': 57, 'S': 114, 'W': 55}
# Progress: {'N': 83038, 'E': 85024, 'S': 82194, 'W': 73124}
# Direction: S4
# Way point: {'N': 67, 'E': 57, 'S': 118, 'W': 55}
# Progress: {'N': 83038, 'E': 85024, 'S': 82194, 'W': 73124}
# Direction: W1
# Way point: {'N': 67, 'E': 57, 'S': 118, 'W': 56}
# Progress: {'N': 83038, 'E': 85024, 'S': 82194, 'W': 73124}
# Direction: S4
# Way point: {'N': 67, 'E': 57, 'S': 122, 'W': 56}
# Progress: {'N': 83038, 'E': 85024, 'S': 82194, 'W': 73124}
# Direction: F42
# Way point: {'N': 67, 'E': 57, 'S': 122, 'W': 56}
# Progress: {'N': 85852, 'E': 87418, 'S': 87318, 'W': 75476}
# Direction: S5
# Way point: {'N': 67, 'E': 57, 'S': 127, 'W': 56}
# Progress: {'N': 85852, 'E': 87418, 'S': 87318, 'W': 75476}
# Direction: N2
# Way point: {'N': 69, 'E': 57, 'S': 127, 'W': 56}
# Progress: {'N': 85852, 'E': 87418, 'S': 87318, 'W': 75476}
# Direction: E1
# Way point: {'N': 69, 'E': 58, 'S': 127, 'W': 56}
# Progress: {'N': 85852, 'E': 87418, 'S': 87318, 'W': 75476}
# Direction: N4
# Way point: {'N': 73, 'E': 58, 'S': 127, 'W': 56}
# Progress: {'N': 85852, 'E': 87418, 'S': 87318, 'W': 75476}
# Direction: E3
# Way point: {'N': 73, 'E': 61, 'S': 127, 'W': 56}
# Progress: {'N': 85852, 'E': 87418, 'S': 87318, 'W': 75476}
# Direction: R180
# Way point: {'N': 127, 'E': 56, 'S': 73, 'W': 61}
# Progress: {'N': 85852, 'E': 87418, 'S': 87318, 'W': 75476}
# Direction: W3
# Way point: {'N': 127, 'E': 56, 'S': 73, 'W': 64}
# Progress: {'N': 85852, 'E': 87418, 'S': 87318, 'W': 75476}
# Direction: R180
# Way point: {'N': 73, 'E': 64, 'S': 127, 'W': 56}
# Progress: {'N': 85852, 'E': 87418, 'S': 87318, 'W': 75476}
# Direction: N4
# Way point: {'N': 77, 'E': 64, 'S': 127, 'W': 56}
# Progress: {'N': 85852, 'E': 87418, 'S': 87318, 'W': 75476}
# Direction: F47
# Way point: {'N': 77, 'E': 64, 'S': 127, 'W': 56}
# Progress: {'N': 89471, 'E': 90426, 'S': 93287, 'W': 78108}
# Direction: N5
# Way point: {'N': 82, 'E': 64, 'S': 127, 'W': 56}
# Progress: {'N': 89471, 'E': 90426, 'S': 93287, 'W': 78108}
# Direction: W5
# Way point: {'N': 82, 'E': 64, 'S': 127, 'W': 61}
# Progress: {'N': 89471, 'E': 90426, 'S': 93287, 'W': 78108}
# Direction: F55
# Way point: {'N': 82, 'E': 64, 'S': 127, 'W': 61}
# Progress: {'N': 93981, 'E': 93946, 'S': 100272, 'W': 81463}
# Direction: E2
# Way point: {'N': 82, 'E': 66, 'S': 127, 'W': 61}
# Progress: {'N': 93981, 'E': 93946, 'S': 100272, 'W': 81463}
# Direction: F12
# Way point: {'N': 82, 'E': 66, 'S': 127, 'W': 61}
# Progress: {'N': 94965, 'E': 94738, 'S': 101796, 'W': 82195}
# Direction: W3
# Way point: {'N': 82, 'E': 66, 'S': 127, 'W': 64}
# Progress: {'N': 94965, 'E': 94738, 'S': 101796, 'W': 82195}
# Direction: N1
# Way point: {'N': 83, 'E': 66, 'S': 127, 'W': 64}
# Progress: {'N': 94965, 'E': 94738, 'S': 101796, 'W': 82195}
# Direction: R90
# Way point: {'N': 64, 'E': 83, 'S': 66, 'W': 127}
# Progress: {'N': 94965, 'E': 94738, 'S': 101796, 'W': 82195}
# Direction: F55
# Way point: {'N': 64, 'E': 83, 'S': 66, 'W': 127}
# Progress: {'N': 98485, 'E': 99303, 'S': 105426, 'W': 89180}
# Direction: R180
# Way point: {'N': 66, 'E': 127, 'S': 64, 'W': 83}
# Progress: {'N': 98485, 'E': 99303, 'S': 105426, 'W': 89180}
# Direction: F89
# Way point: {'N': 66, 'E': 127, 'S': 64, 'W': 83}
# Progress: {'N': 104359, 'E': 110606, 'S': 111122, 'W': 96567}
# Direction: S4
# Way point: {'N': 66, 'E': 127, 'S': 68, 'W': 83}
# Progress: {'N': 104359, 'E': 110606, 'S': 111122, 'W': 96567}
# Direction: F38
# Way point: {'N': 66, 'E': 127, 'S': 68, 'W': 83}
# Progress: {'N': 106867, 'E': 115432, 'S': 113706, 'W': 99721}
# Direction: S5
# Way point: {'N': 66, 'E': 127, 'S': 73, 'W': 83}
# Progress: {'N': 106867, 'E': 115432, 'S': 113706, 'W': 99721}
# Direction: R180
# Way point: {'N': 73, 'E': 83, 'S': 66, 'W': 127}
# Progress: {'N': 106867, 'E': 115432, 'S': 113706, 'W': 99721}
# Direction: N2
# Way point: {'N': 75, 'E': 83, 'S': 66, 'W': 127}
# Progress: {'N': 106867, 'E': 115432, 'S': 113706, 'W': 99721}
# Direction: W4
# Way point: {'N': 75, 'E': 83, 'S': 66, 'W': 131}
# Progress: {'N': 106867, 'E': 115432, 'S': 113706, 'W': 99721}
# Direction: F16
# Way point: {'N': 75, 'E': 83, 'S': 66, 'W': 131}
# Progress: {'N': 108067, 'E': 116760, 'S': 114762, 'W': 101817}
# Direction: N2
# Way point: {'N': 77, 'E': 83, 'S': 66, 'W': 131}
# Progress: {'N': 108067, 'E': 116760, 'S': 114762, 'W': 101817}
# Direction: R180
# Way point: {'N': 66, 'E': 131, 'S': 77, 'W': 83}
# Progress: {'N': 108067, 'E': 116760, 'S': 114762, 'W': 101817}
# Direction: E2
# Way point: {'N': 66, 'E': 133, 'S': 77, 'W': 83}
# Progress: {'N': 108067, 'E': 116760, 'S': 114762, 'W': 101817}
# Direction: R180
# Way point: {'N': 77, 'E': 83, 'S': 66, 'W': 133}
# Progress: {'N': 108067, 'E': 116760, 'S': 114762, 'W': 101817}
# Direction: W1
# Way point: {'N': 77, 'E': 83, 'S': 66, 'W': 134}
# Progress: {'N': 108067, 'E': 116760, 'S': 114762, 'W': 101817}
# Direction: R90
# Way point: {'N': 134, 'E': 77, 'S': 83, 'W': 66}
# Progress: {'N': 108067, 'E': 116760, 'S': 114762, 'W': 101817}
# Direction: F50
# Way point: {'N': 134, 'E': 77, 'S': 83, 'W': 66}
# Progress: {'N': 114767, 'E': 120610, 'S': 118912, 'W': 105117}
# Direction: E1
# Way point: {'N': 134, 'E': 78, 'S': 83, 'W': 66}
# Progress: {'N': 114767, 'E': 120610, 'S': 118912, 'W': 105117}
# Direction: F36
# Way point: {'N': 134, 'E': 78, 'S': 83, 'W': 66}
# Progress: {'N': 119591, 'E': 123418, 'S': 121900, 'W': 107493}
# Direction: W4
# Way point: {'N': 134, 'E': 78, 'S': 83, 'W': 70}
# Progress: {'N': 119591, 'E': 123418, 'S': 121900, 'W': 107493}
# Direction: F79
# Way point: {'N': 134, 'E': 78, 'S': 83, 'W': 70}
# Progress: {'N': 130177, 'E': 129580, 'S': 128457, 'W': 113023}
# Direction: E3
# Way point: {'N': 134, 'E': 81, 'S': 83, 'W': 70}
# Progress: {'N': 130177, 'E': 129580, 'S': 128457, 'W': 113023}
# Direction: F19
# Way point: {'N': 134, 'E': 81, 'S': 83, 'W': 70}
# Progress: {'N': 132723, 'E': 131119, 'S': 130034, 'W': 114353}
# Direction: N4
# Way point: {'N': 138, 'E': 81, 'S': 83, 'W': 70}
# Progress: {'N': 132723, 'E': 131119, 'S': 130034, 'W': 114353}
# Direction: L270
# Way point: {'N': 70, 'E': 138, 'S': 81, 'W': 83}
# Progress: {'N': 132723, 'E': 131119, 'S': 130034, 'W': 114353}
# Direction: N5
# Way point: {'N': 75, 'E': 138, 'S': 81, 'W': 83}
# Progress: {'N': 132723, 'E': 131119, 'S': 130034, 'W': 114353}
# Direction: W3
# Way point: {'N': 75, 'E': 138, 'S': 81, 'W': 86}
# Progress: {'N': 132723, 'E': 131119, 'S': 130034, 'W': 114353}
# Direction: F48
# Way point: {'N': 75, 'E': 138, 'S': 81, 'W': 86}
# Progress: {'N': 136323, 'E': 137743, 'S': 133922, 'W': 118481}
# Direction: R90
# Way point: {'N': 86, 'E': 75, 'S': 138, 'W': 81}
# Progress: {'N': 136323, 'E': 137743, 'S': 133922, 'W': 118481}
# Direction: F36
# Way point: {'N': 86, 'E': 75, 'S': 138, 'W': 81}
# Progress: {'N': 139419, 'E': 140443, 'S': 138890, 'W': 121397}
# Direction: S5
# Way point: {'N': 86, 'E': 75, 'S': 143, 'W': 81}
# Progress: {'N': 139419, 'E': 140443, 'S': 138890, 'W': 121397}
# Direction: F100
# Way point: {'N': 86, 'E': 75, 'S': 143, 'W': 81}
# Progress: {'N': 148019, 'E': 147943, 'S': 153190, 'W': 129497}
# Direction: E3
# Way point: {'N': 86, 'E': 78, 'S': 143, 'W': 81}
# Progress: {'N': 148019, 'E': 147943, 'S': 153190, 'W': 129497}
# Direction: F55
# Way point: {'N': 86, 'E': 78, 'S': 143, 'W': 81}
# Progress: {'N': 152749, 'E': 152233, 'S': 161055, 'W': 133952}
# Direction: N3
# Way point: {'N': 89, 'E': 78, 'S': 143, 'W': 81}
# Progress: {'N': 152749, 'E': 152233, 'S': 161055, 'W': 133952}
# Direction: F16
# Way point: {'N': 89, 'E': 78, 'S': 143, 'W': 81}
# Progress: {'N': 154173, 'E': 153481, 'S': 163343, 'W': 135248}
# Direction: R180
# Way point: {'N': 143, 'E': 81, 'S': 89, 'W': 78}
# Progress: {'N': 154173, 'E': 153481, 'S': 163343, 'W': 135248}
# Direction: S5
# Way point: {'N': 143, 'E': 81, 'S': 94, 'W': 78}
# Progress: {'N': 154173, 'E': 153481, 'S': 163343, 'W': 135248}
# Direction: N3
# Way point: {'N': 146, 'E': 81, 'S': 94, 'W': 78}
# Progress: {'N': 154173, 'E': 153481, 'S': 163343, 'W': 135248}
# Direction: R180
# Way point: {'N': 94, 'E': 78, 'S': 146, 'W': 81}
# Progress: {'N': 154173, 'E': 153481, 'S': 163343, 'W': 135248}
# Direction: N1
# Way point: {'N': 95, 'E': 78, 'S': 146, 'W': 81}
# Progress: {'N': 154173, 'E': 153481, 'S': 163343, 'W': 135248}
# Direction: F8
# Way point: {'N': 95, 'E': 78, 'S': 146, 'W': 81}
# Progress: {'N': 154933, 'E': 154105, 'S': 164511, 'W': 135896}
# Direction: E5
# Way point: {'N': 95, 'E': 83, 'S': 146, 'W': 81}
# Progress: {'N': 154933, 'E': 154105, 'S': 164511, 'W': 135896}
# Direction: L90
# Way point: {'N': 83, 'E': 146, 'S': 81, 'W': 95}
# Progress: {'N': 154933, 'E': 154105, 'S': 164511, 'W': 135896}
# Direction: F21
# Way point: {'N': 83, 'E': 146, 'S': 81, 'W': 95}
# Progress: {'N': 156676, 'E': 157171, 'S': 166212, 'W': 137891}
# Direction: L90
# Way point: {'N': 146, 'E': 81, 'S': 95, 'W': 83}
# Progress: {'N': 156676, 'E': 157171, 'S': 166212, 'W': 137891}
# Direction: F80
# Way point: {'N': 146, 'E': 81, 'S': 95, 'W': 83}
# Progress: {'N': 168356, 'E': 163651, 'S': 173812, 'W': 144531}
# Direction: L90
# Way point: {'N': 81, 'E': 95, 'S': 83, 'W': 146}
# Progress: {'N': 168356, 'E': 163651, 'S': 173812, 'W': 144531}
# Direction: N5
# Way point: {'N': 86, 'E': 95, 'S': 83, 'W': 146}
# Progress: {'N': 168356, 'E': 163651, 'S': 173812, 'W': 144531}
# Direction: W5
# Way point: {'N': 86, 'E': 95, 'S': 83, 'W': 151}
# Progress: {'N': 168356, 'E': 163651, 'S': 173812, 'W': 144531}
# Direction: S5
# Way point: {'N': 86, 'E': 95, 'S': 88, 'W': 151}
# Progress: {'N': 168356, 'E': 163651, 'S': 173812, 'W': 144531}
# Direction: E5
# Way point: {'N': 86, 'E': 100, 'S': 88, 'W': 151}
# Progress: {'N': 168356, 'E': 163651, 'S': 173812, 'W': 144531}
# Direction: R90
# Way point: {'N': 151, 'E': 86, 'S': 100, 'W': 88}
# Progress: {'N': 168356, 'E': 163651, 'S': 173812, 'W': 144531}
# Direction: N4
# Way point: {'N': 155, 'E': 86, 'S': 100, 'W': 88}
# Progress: {'N': 168356, 'E': 163651, 'S': 173812, 'W': 144531}
# Direction: E1
# Way point: {'N': 155, 'E': 87, 'S': 100, 'W': 88}
# Progress: {'N': 168356, 'E': 163651, 'S': 173812, 'W': 144531}
# Direction: F20
# Way point: {'N': 155, 'E': 87, 'S': 100, 'W': 88}
# Progress: {'N': 171456, 'E': 165391, 'S': 175812, 'W': 146291}
# Direction: S3
# Way point: {'N': 155, 'E': 87, 'S': 103, 'W': 88}
# Progress: {'N': 171456, 'E': 165391, 'S': 175812, 'W': 146291}
# Direction: L90
# Way point: {'N': 87, 'E': 103, 'S': 88, 'W': 155}
# Progress: {'N': 171456, 'E': 165391, 'S': 175812, 'W': 146291}
# Direction: E1
# Way point: {'N': 87, 'E': 104, 'S': 88, 'W': 155}
# Progress: {'N': 171456, 'E': 165391, 'S': 175812, 'W': 146291}
# Direction: N4
# Way point: {'N': 91, 'E': 104, 'S': 88, 'W': 155}
# Progress: {'N': 171456, 'E': 165391, 'S': 175812, 'W': 146291}
# Direction: F16
# Way point: {'N': 91, 'E': 104, 'S': 88, 'W': 155}
# Progress: {'N': 172912, 'E': 167055, 'S': 177220, 'W': 148771}
# Direction: F26
# Way point: {'N': 91, 'E': 104, 'S': 88, 'W': 155}
# Progress: {'N': 175278, 'E': 169759, 'S': 179508, 'W': 152801}
# Direction: E1
# Way point: {'N': 91, 'E': 105, 'S': 88, 'W': 155}
# Progress: {'N': 175278, 'E': 169759, 'S': 179508, 'W': 152801}
# Direction: F75
# Way point: {'N': 91, 'E': 105, 'S': 88, 'W': 155}
# Progress: {'N': 182103, 'E': 177634, 'S': 186108, 'W': 164426}
# Direction: E1
# Way point: {'N': 91, 'E': 106, 'S': 88, 'W': 155}
# Progress: {'N': 182103, 'E': 177634, 'S': 186108, 'W': 164426}
# Direction: R90
# Way point: {'N': 155, 'E': 91, 'S': 106, 'W': 88}
# Progress: {'N': 182103, 'E': 177634, 'S': 186108, 'W': 164426}
# Direction: F69
# Way point: {'N': 155, 'E': 91, 'S': 106, 'W': 88}
# Progress: {'N': 192798, 'E': 183913, 'S': 193422, 'W': 170498}
# Direction: N1
# Way point: {'N': 156, 'E': 91, 'S': 106, 'W': 88}
# Progress: {'N': 192798, 'E': 183913, 'S': 193422, 'W': 170498}
# Direction: E3
# Way point: {'N': 156, 'E': 94, 'S': 106, 'W': 88}
# Progress: {'N': 192798, 'E': 183913, 'S': 193422, 'W': 170498}
# Direction: R90
# Way point: {'N': 88, 'E': 156, 'S': 94, 'W': 106}
# Progress: {'N': 192798, 'E': 183913, 'S': 193422, 'W': 170498}
# Direction: F62
# Way point: {'N': 88, 'E': 156, 'S': 94, 'W': 106}
# Progress: {'N': 198254, 'E': 193585, 'S': 199250, 'W': 177070}
# Direction: L180
# Way point: {'N': 94, 'E': 106, 'S': 88, 'W': 156}
# Progress: {'N': 198254, 'E': 193585, 'S': 199250, 'W': 177070}
# Direction: W4
# Way point: {'N': 94, 'E': 106, 'S': 88, 'W': 160}
# Progress: {'N': 198254, 'E': 193585, 'S': 199250, 'W': 177070}
# Direction: F80
# Way point: {'N': 94, 'E': 106, 'S': 88, 'W': 160}
# Progress: {'N': 205774, 'E': 202065, 'S': 206290, 'W': 189870}
# Direction: S5
# Way point: {'N': 94, 'E': 106, 'S': 93, 'W': 160}
# Progress: {'N': 205774, 'E': 202065, 'S': 206290, 'W': 189870}
# Direction: L90
# Way point: {'N': 106, 'E': 93, 'S': 160, 'W': 94}
# Progress: {'N': 205774, 'E': 202065, 'S': 206290, 'W': 189870}
# Direction: F90
# Way point: {'N': 106, 'E': 93, 'S': 160, 'W': 94}
# Progress: {'N': 215314, 'E': 210435, 'S': 220690, 'W': 198330}
# Direction: W5
# Way point: {'N': 106, 'E': 93, 'S': 160, 'W': 99}
# Progress: {'N': 215314, 'E': 210435, 'S': 220690, 'W': 198330}
# Direction: F40
# Way point: {'N': 106, 'E': 93, 'S': 160, 'W': 99}
# Progress: {'N': 219554, 'E': 214155, 'S': 227090, 'W': 202290}
# Direction: W1
# Way point: {'N': 106, 'E': 93, 'S': 160, 'W': 100}
# Progress: {'N': 219554, 'E': 214155, 'S': 227090, 'W': 202290}
# Direction: L90
# Way point: {'N': 93, 'E': 160, 'S': 100, 'W': 106}
# Progress: {'N': 219554, 'E': 214155, 'S': 227090, 'W': 202290}
# Direction: W1
# Way point: {'N': 93, 'E': 160, 'S': 100, 'W': 107}
# Progress: {'N': 219554, 'E': 214155, 'S': 227090, 'W': 202290}
# Direction: R180
# Way point: {'N': 100, 'E': 107, 'S': 93, 'W': 160}
# Progress: {'N': 219554, 'E': 214155, 'S': 227090, 'W': 202290}
# Direction: S2
# Way point: {'N': 100, 'E': 107, 'S': 95, 'W': 160}
# Progress: {'N': 219554, 'E': 214155, 'S': 227090, 'W': 202290}
# Direction: F65
# Way point: {'N': 100, 'E': 107, 'S': 95, 'W': 160}
# Progress: {'N': 226054, 'E': 221110, 'S': 233265, 'W': 212690}
# Direction: E2
# Way point: {'N': 100, 'E': 109, 'S': 95, 'W': 160}
# Progress: {'N': 226054, 'E': 221110, 'S': 233265, 'W': 212690}
# Direction: R180
# Way point: {'N': 95, 'E': 160, 'S': 100, 'W': 109}
# Progress: {'N': 226054, 'E': 221110, 'S': 233265, 'W': 212690}
# Direction: E1
# Way point: {'N': 95, 'E': 161, 'S': 100, 'W': 109}
# Progress: {'N': 226054, 'E': 221110, 'S': 233265, 'W': 212690}
# Direction: F37
# Way point: {'N': 95, 'E': 161, 'S': 100, 'W': 109}
# Progress: {'N': 229569, 'E': 227067, 'S': 236965, 'W': 216723}
# Direction: E5
# Way point: {'N': 95, 'E': 166, 'S': 100, 'W': 109}
# Progress: {'N': 229569, 'E': 227067, 'S': 236965, 'W': 216723}
# Direction: R90
# Way point: {'N': 109, 'E': 95, 'S': 166, 'W': 100}
# Progress: {'N': 229569, 'E': 227067, 'S': 236965, 'W': 216723}
# Direction: N3
# Way point: {'N': 112, 'E': 95, 'S': 166, 'W': 100}
# Progress: {'N': 229569, 'E': 227067, 'S': 236965, 'W': 216723}
# Direction: W4
# Way point: {'N': 112, 'E': 95, 'S': 166, 'W': 104}
# Progress: {'N': 229569, 'E': 227067, 'S': 236965, 'W': 216723}
# Direction: S5
# Way point: {'N': 112, 'E': 95, 'S': 171, 'W': 104}
# Progress: {'N': 229569, 'E': 227067, 'S': 236965, 'W': 216723}
# Direction: E3
# Way point: {'N': 112, 'E': 98, 'S': 171, 'W': 104}
# Progress: {'N': 229569, 'E': 227067, 'S': 236965, 'W': 216723}
# Direction: F36
# Way point: {'N': 112, 'E': 98, 'S': 171, 'W': 104}
# Progress: {'N': 233601, 'E': 230595, 'S': 243121, 'W': 220467}
# Direction: F8
# Way point: {'N': 112, 'E': 98, 'S': 171, 'W': 104}
# Progress: {'N': 234497, 'E': 231379, 'S': 244489, 'W': 221299}
# Direction: W5
# Way point: {'N': 112, 'E': 98, 'S': 171, 'W': 109}
# Progress: {'N': 234497, 'E': 231379, 'S': 244489, 'W': 221299}
# Direction: L90
# Way point: {'N': 98, 'E': 171, 'S': 109, 'W': 112}
# Progress: {'N': 234497, 'E': 231379, 'S': 244489, 'W': 221299}
# Direction: F54
# Way point: {'N': 98, 'E': 171, 'S': 109, 'W': 112}
# Progress: {'N': 239789, 'E': 240613, 'S': 250375, 'W': 227347}
# Direction: N5
# Way point: {'N': 103, 'E': 171, 'S': 109, 'W': 112}
# Progress: {'N': 239789, 'E': 240613, 'S': 250375, 'W': 227347}
# Direction: L180
# Way point: {'N': 109, 'E': 112, 'S': 103, 'W': 171}
# Progress: {'N': 239789, 'E': 240613, 'S': 250375, 'W': 227347}
# Direction: S4
# Way point: {'N': 109, 'E': 112, 'S': 107, 'W': 171}
# Progress: {'N': 239789, 'E': 240613, 'S': 250375, 'W': 227347}
# Direction: L90
# Way point: {'N': 112, 'E': 107, 'S': 171, 'W': 109}
# Progress: {'N': 239789, 'E': 240613, 'S': 250375, 'W': 227347}
# Direction: F88
# Way point: {'N': 112, 'E': 107, 'S': 171, 'W': 109}
# Progress: {'N': 249645, 'E': 250029, 'S': 265423, 'W': 236939}
# Direction: R180
# Way point: {'N': 171, 'E': 109, 'S': 112, 'W': 107}
# Progress: {'N': 249645, 'E': 250029, 'S': 265423, 'W': 236939}
# Direction: F46
# Way point: {'N': 171, 'E': 109, 'S': 112, 'W': 107}
# Progress: {'N': 257511, 'E': 255043, 'S': 270575, 'W': 241861}
# Direction: N5
# Way point: {'N': 176, 'E': 109, 'S': 112, 'W': 107}
# Progress: {'N': 257511, 'E': 255043, 'S': 270575, 'W': 241861}
# Direction: E3
# Way point: {'N': 176, 'E': 112, 'S': 112, 'W': 107}
# Progress: {'N': 257511, 'E': 255043, 'S': 270575, 'W': 241861}
# Direction: F93
# Way point: {'N': 176, 'E': 112, 'S': 112, 'W': 107}
# Progress: {'N': 273879, 'E': 265459, 'S': 280991, 'W': 251812}
# Direction: S2
# Way point: {'N': 176, 'E': 112, 'S': 114, 'W': 107}
# Progress: {'N': 273879, 'E': 265459, 'S': 280991, 'W': 251812}
# Direction: E5
# Way point: {'N': 176, 'E': 117, 'S': 114, 'W': 107}
# Progress: {'N': 273879, 'E': 265459, 'S': 280991, 'W': 251812}
# Direction: R270
# Way point: {'N': 117, 'E': 114, 'S': 107, 'W': 176}
# Progress: {'N': 273879, 'E': 265459, 'S': 280991, 'W': 251812}
# Direction: F15
# Way point: {'N': 117, 'E': 114, 'S': 107, 'W': 176}
# Progress: {'N': 275634, 'E': 267169, 'S': 282596, 'W': 254452}
# Direction: R90
# Way point: {'N': 176, 'E': 117, 'S': 114, 'W': 107}
# Progress: {'N': 275634, 'E': 267169, 'S': 282596, 'W': 254452}
# Direction: F28
# Way point: {'N': 176, 'E': 117, 'S': 114, 'W': 107}
# Progress: {'N': 280562, 'E': 270445, 'S': 285788, 'W': 257448}
# Direction: S2
# Way point: {'N': 176, 'E': 117, 'S': 116, 'W': 107}
# Progress: {'N': 280562, 'E': 270445, 'S': 285788, 'W': 257448}
# Direction: F61
# Way point: {'N': 176, 'E': 117, 'S': 116, 'W': 107}
# Progress: {'N': 291298, 'E': 277582, 'S': 292864, 'W': 263975}
# Direction: N5
# Way point: {'N': 181, 'E': 117, 'S': 116, 'W': 107}
# Progress: {'N': 291298, 'E': 277582, 'S': 292864, 'W': 263975}
# Direction: L90
# Way point: {'N': 117, 'E': 116, 'S': 107, 'W': 181}
# Progress: {'N': 291298, 'E': 277582, 'S': 292864, 'W': 263975}
# Direction: W3
# Way point: {'N': 117, 'E': 116, 'S': 107, 'W': 184}
# Progress: {'N': 291298, 'E': 277582, 'S': 292864, 'W': 263975}
# Direction: S5
# Way point: {'N': 117, 'E': 116, 'S': 112, 'W': 184}
# Progress: {'N': 291298, 'E': 277582, 'S': 292864, 'W': 263975}
# Direction: L90
# Way point: {'N': 116, 'E': 112, 'S': 184, 'W': 117}
# Progress: {'N': 291298, 'E': 277582, 'S': 292864, 'W': 263975}
# Direction: N1
# Way point: {'N': 117, 'E': 112, 'S': 184, 'W': 117}
# Progress: {'N': 291298, 'E': 277582, 'S': 292864, 'W': 263975}
# Direction: L90
# Way point: {'N': 112, 'E': 184, 'S': 117, 'W': 117}
# Progress: {'N': 291298, 'E': 277582, 'S': 292864, 'W': 263975}
# Direction: F41
# Way point: {'N': 112, 'E': 184, 'S': 117, 'W': 117}
# Progress: {'N': 295890, 'E': 285126, 'S': 297661, 'W': 268772}
# Direction: W4
# Way point: {'N': 112, 'E': 184, 'S': 117, 'W': 121}
# Progress: {'N': 295890, 'E': 285126, 'S': 297661, 'W': 268772}
# Direction: N3
# Way point: {'N': 115, 'E': 184, 'S': 117, 'W': 121}
# Progress: {'N': 295890, 'E': 285126, 'S': 297661, 'W': 268772}
# Direction: F4
# Way point: {'N': 115, 'E': 184, 'S': 117, 'W': 121}
# Progress: {'N': 296350, 'E': 285862, 'S': 298129, 'W': 269256}
# Direction: N3
# Way point: {'N': 118, 'E': 184, 'S': 117, 'W': 121}
# Progress: {'N': 296350, 'E': 285862, 'S': 298129, 'W': 269256}
# Direction: F35
# Way point: {'N': 118, 'E': 184, 'S': 117, 'W': 121}
# Progress: {'N': 300480, 'E': 292302, 'S': 302224, 'W': 273491}
# Direction: R90
# Way point: {'N': 121, 'E': 118, 'S': 184, 'W': 117}
# Progress: {'N': 300480, 'E': 292302, 'S': 302224, 'W': 273491}
# Direction: W5
# Way point: {'N': 121, 'E': 118, 'S': 184, 'W': 122}
# Progress: {'N': 300480, 'E': 292302, 'S': 302224, 'W': 273491}
# Direction: F69
# Way point: {'N': 121, 'E': 118, 'S': 184, 'W': 122}
# Progress: {'N': 308829, 'E': 300444, 'S': 314920, 'W': 281909}
# Direction: L90
# Way point: {'N': 118, 'E': 184, 'S': 122, 'W': 121}
# Progress: {'N': 308829, 'E': 300444, 'S': 314920, 'W': 281909}
# Direction: E3
# Way point: {'N': 118, 'E': 187, 'S': 122, 'W': 121}
# Progress: {'N': 308829, 'E': 300444, 'S': 314920, 'W': 281909}
# Direction: R90
# Way point: {'N': 121, 'E': 118, 'S': 187, 'W': 122}
# Progress: {'N': 308829, 'E': 300444, 'S': 314920, 'W': 281909}
# Direction: N2
# Way point: {'N': 123, 'E': 118, 'S': 187, 'W': 122}
# Progress: {'N': 308829, 'E': 300444, 'S': 314920, 'W': 281909}
# Direction: W4
# Way point: {'N': 123, 'E': 118, 'S': 187, 'W': 126}
# Progress: {'N': 308829, 'E': 300444, 'S': 314920, 'W': 281909}
# Direction: N5
# Way point: {'N': 128, 'E': 118, 'S': 187, 'W': 126}
# Progress: {'N': 308829, 'E': 300444, 'S': 314920, 'W': 281909}
# Direction: E4
# Way point: {'N': 128, 'E': 122, 'S': 187, 'W': 126}
# Progress: {'N': 308829, 'E': 300444, 'S': 314920, 'W': 281909}
# Direction: R90
# Way point: {'N': 126, 'E': 128, 'S': 122, 'W': 187}
# Progress: {'N': 308829, 'E': 300444, 'S': 314920, 'W': 281909}
# Direction: N1
# Way point: {'N': 127, 'E': 128, 'S': 122, 'W': 187}
# Progress: {'N': 308829, 'E': 300444, 'S': 314920, 'W': 281909}
# Direction: R90
# Way point: {'N': 187, 'E': 127, 'S': 128, 'W': 122}
# Progress: {'N': 308829, 'E': 300444, 'S': 314920, 'W': 281909}
# Direction: N2
# Way point: {'N': 189, 'E': 127, 'S': 128, 'W': 122}
# Progress: {'N': 308829, 'E': 300444, 'S': 314920, 'W': 281909}
# Direction: F44
# Way point: {'N': 189, 'E': 127, 'S': 128, 'W': 122}
# Progress: {'N': 317145, 'E': 306032, 'S': 320552, 'W': 287277}
# Direction: L90
# Way point: {'N': 127, 'E': 128, 'S': 122, 'W': 189}
# Progress: {'N': 317145, 'E': 306032, 'S': 320552, 'W': 287277}
# Direction: F15
# Way point: {'N': 127, 'E': 128, 'S': 122, 'W': 189}
# Progress: {'N': 319050, 'E': 307952, 'S': 322382, 'W': 290112}
# Direction: W2
# Way point: {'N': 127, 'E': 128, 'S': 122, 'W': 191}
# Progress: {'N': 319050, 'E': 307952, 'S': 322382, 'W': 290112}
# Direction: R180
# Way point: {'N': 122, 'E': 191, 'S': 127, 'W': 128}
# Progress: {'N': 319050, 'E': 307952, 'S': 322382, 'W': 290112}
# Direction: E3
# Way point: {'N': 122, 'E': 194, 'S': 127, 'W': 128}
# Progress: {'N': 319050, 'E': 307952, 'S': 322382, 'W': 290112}
# Direction: L90
# Way point: {'N': 194, 'E': 127, 'S': 128, 'W': 122}
# Progress: {'N': 319050, 'E': 307952, 'S': 322382, 'W': 290112}
# Direction: F26
# Way point: {'N': 194, 'E': 127, 'S': 128, 'W': 122}
# Progress: {'N': 324094, 'E': 311254, 'S': 325710, 'W': 293284}
# Direction: L90
# Way point: {'N': 127, 'E': 128, 'S': 122, 'W': 194}
# Progress: {'N': 324094, 'E': 311254, 'S': 325710, 'W': 293284}
# Direction: S4
# Way point: {'N': 127, 'E': 128, 'S': 126, 'W': 194}
# Progress: {'N': 324094, 'E': 311254, 'S': 325710, 'W': 293284}
# Direction: W4
# Way point: {'N': 127, 'E': 128, 'S': 126, 'W': 198}
# Progress: {'N': 324094, 'E': 311254, 'S': 325710, 'W': 293284}
# Direction: S1
# Way point: {'N': 127, 'E': 128, 'S': 127, 'W': 198}
# Progress: {'N': 324094, 'E': 311254, 'S': 325710, 'W': 293284}
# Direction: F46
# Way point: {'N': 127, 'E': 128, 'S': 127, 'W': 198}
# Progress: {'N': 329936, 'E': 317142, 'S': 331552, 'W': 302392}
# Direction: E2
# Way point: {'N': 127, 'E': 130, 'S': 127, 'W': 198}
# Progress: {'N': 329936, 'E': 317142, 'S': 331552, 'W': 302392}
# Direction: S5
# Way point: {'N': 127, 'E': 130, 'S': 132, 'W': 198}
# Progress: {'N': 329936, 'E': 317142, 'S': 331552, 'W': 302392}
# Direction: R180
# Way point: {'N': 132, 'E': 198, 'S': 127, 'W': 130}
# Progress: {'N': 329936, 'E': 317142, 'S': 331552, 'W': 302392}
# Direction: W3
# Way point: {'N': 132, 'E': 198, 'S': 127, 'W': 133}
# Progress: {'N': 329936, 'E': 317142, 'S': 331552, 'W': 302392}
# Direction: F6
# Way point: {'N': 132, 'E': 198, 'S': 127, 'W': 133}
# Progress: {'N': 330728, 'E': 318330, 'S': 332314, 'W': 303190}
# Direction: L90
# Way point: {'N': 198, 'E': 127, 'S': 133, 'W': 132}
# Progress: {'N': 330728, 'E': 318330, 'S': 332314, 'W': 303190}
# Direction: W3
# Way point: {'N': 198, 'E': 127, 'S': 133, 'W': 135}
# Progress: {'N': 330728, 'E': 318330, 'S': 332314, 'W': 303190}
# Direction: F99
# Way point: {'N': 198, 'E': 127, 'S': 133, 'W': 135}
# Progress: {'N': 350330, 'E': 330903, 'S': 345481, 'W': 316555}
# Direction: E3
# Way point: {'N': 198, 'E': 130, 'S': 133, 'W': 135}
# Progress: {'N': 350330, 'E': 330903, 'S': 345481, 'W': 316555}
# Direction: L90
# Way point: {'N': 130, 'E': 133, 'S': 135, 'W': 198}
# Progress: {'N': 350330, 'E': 330903, 'S': 345481, 'W': 316555}
# Direction: S1
# Way point: {'N': 130, 'E': 133, 'S': 136, 'W': 198}
# Progress: {'N': 350330, 'E': 330903, 'S': 345481, 'W': 316555}
# Direction: E1
# Way point: {'N': 130, 'E': 134, 'S': 136, 'W': 198}
# Progress: {'N': 350330, 'E': 330903, 'S': 345481, 'W': 316555}
# Direction: N2
# Way point: {'N': 132, 'E': 134, 'S': 136, 'W': 198}
# Progress: {'N': 350330, 'E': 330903, 'S': 345481, 'W': 316555}
# Direction: L90
# Way point: {'N': 134, 'E': 136, 'S': 198, 'W': 132}
# Progress: {'N': 350330, 'E': 330903, 'S': 345481, 'W': 316555}
# Direction: N3
# Way point: {'N': 137, 'E': 136, 'S': 198, 'W': 132}
# Progress: {'N': 350330, 'E': 330903, 'S': 345481, 'W': 316555}
# Direction: E4
# Way point: {'N': 137, 'E': 140, 'S': 198, 'W': 132}
# Progress: {'N': 350330, 'E': 330903, 'S': 345481, 'W': 316555}
# Direction: N3
# Way point: {'N': 140, 'E': 140, 'S': 198, 'W': 132}
# Progress: {'N': 350330, 'E': 330903, 'S': 345481, 'W': 316555}
# Direction: W1
# Way point: {'N': 140, 'E': 140, 'S': 198, 'W': 133}
# Progress: {'N': 350330, 'E': 330903, 'S': 345481, 'W': 316555}
# Direction: F87
# Way point: {'N': 140, 'E': 140, 'S': 198, 'W': 133}
# Progress: {'N': 362510, 'E': 343083, 'S': 362707, 'W': 328126}
# Direction: N2
# Way point: {'N': 142, 'E': 140, 'S': 198, 'W': 133}
# Progress: {'N': 362510, 'E': 343083, 'S': 362707, 'W': 328126}
# Direction: L180
# Way point: {'N': 198, 'E': 133, 'S': 142, 'W': 140}
# Progress: {'N': 362510, 'E': 343083, 'S': 362707, 'W': 328126}
# Direction: E1
# Way point: {'N': 198, 'E': 134, 'S': 142, 'W': 140}
# Progress: {'N': 362510, 'E': 343083, 'S': 362707, 'W': 328126}
# Direction: S1
# Way point: {'N': 198, 'E': 134, 'S': 143, 'W': 140}
# ...
# Progress: {'N': 1077943, 'E': 1056877, 'S': 1090139, 'W': 1018644}
# Direction: W5
# Way point: {'N': 240, 'E': 228, 'S': 289, 'W': 256}
# Progress: {'N': 1077943, 'E': 1056877, 'S': 1090139, 'W': 1018644}
# Direction: E1
# Way point: {'N': 240, 'E': 229, 'S': 289, 'W': 256}
# Progress: {'N': 1077943, 'E': 1056877, 'S': 1090139, 'W': 1018644}
# Direction: L90
# Way point: {'N': 229, 'E': 289, 'S': 256, 'W': 240}
# Progress: {'N': 1077943, 'E': 1056877, 'S': 1090139, 'W': 1018644}
# Direction: E3
# Way point: {'N': 229, 'E': 292, 'S': 256, 'W': 240}
# Progress: {'N': 1077943, 'E': 1056877, 'S': 1090139, 'W': 1018644}
# Direction: R90
# Way point: {'N': 240, 'E': 229, 'S': 292, 'W': 256}
# Progress: {'N': 1077943, 'E': 1056877, 'S': 1090139, 'W': 1018644}
# Direction: N5
# Way point: {'N': 245, 'E': 229, 'S': 292, 'W': 256}
# Progress: {'N': 1077943, 'E': 1056877, 'S': 1090139, 'W': 1018644}
# Direction: L270
# Way point: {'N': 256, 'E': 245, 'S': 229, 'W': 292}
# Progress: {'N': 1077943, 'E': 1056877, 'S': 1090139, 'W': 1018644}
# Direction: N5
# Way point: {'N': 261, 'E': 245, 'S': 229, 'W': 292}
# Progress: {'N': 1077943, 'E': 1056877, 'S': 1090139, 'W': 1018644}
# Direction: F77
# Way point: {'N': 261, 'E': 245, 'S': 229, 'W': 292}
# Progress: {'N': 1098040, 'E': 1075742, 'S': 1107772, 'W': 1041128}
# Direction: W4
# Way point: {'N': 261, 'E': 245, 'S': 229, 'W': 296}
# Progress: {'N': 1098040, 'E': 1075742, 'S': 1107772, 'W': 1041128}
# Direction: N5
# Way point: {'N': 266, 'E': 245, 'S': 229, 'W': 296}
# Progress: {'N': 1098040, 'E': 1075742, 'S': 1107772, 'W': 1041128}
# Direction: E4
# Way point: {'N': 266, 'E': 249, 'S': 229, 'W': 296}
# Progress: {'N': 1098040, 'E': 1075742, 'S': 1107772, 'W': 1041128}
# Direction: L90
# Way point: {'N': 249, 'E': 229, 'S': 296, 'W': 266}
# Progress: {'N': 1098040, 'E': 1075742, 'S': 1107772, 'W': 1041128}
# Direction: E2
# Way point: {'N': 249, 'E': 231, 'S': 296, 'W': 266}
# Progress: {'N': 1098040, 'E': 1075742, 'S': 1107772, 'W': 1041128}
# Direction: L180
# Way point: {'N': 296, 'E': 266, 'S': 249, 'W': 231}
# Progress: {'N': 1098040, 'E': 1075742, 'S': 1107772, 'W': 1041128}
# Direction: F13
# Way point: {'N': 296, 'E': 266, 'S': 249, 'W': 231}
# Progress: {'N': 1101888, 'E': 1079200, 'S': 1111009, 'W': 1044131}
# Direction: E5
# Way point: {'N': 296, 'E': 271, 'S': 249, 'W': 231}
# Progress: {'N': 1101888, 'E': 1079200, 'S': 1111009, 'W': 1044131}
# Direction: L270
# Way point: {'N': 231, 'E': 296, 'S': 271, 'W': 249}
# Progress: {'N': 1101888, 'E': 1079200, 'S': 1111009, 'W': 1044131}
# Direction: W1
# Way point: {'N': 231, 'E': 296, 'S': 271, 'W': 250}
# Progress: {'N': 1101888, 'E': 1079200, 'S': 1111009, 'W': 1044131}
# Direction: F52
# Way point: {'N': 231, 'E': 296, 'S': 271, 'W': 250}
# Progress: {'N': 1113900, 'E': 1094592, 'S': 1125101, 'W': 1057131}
# Direction: L90
# Way point: {'N': 296, 'E': 271, 'S': 250, 'W': 231}
# Progress: {'N': 1113900, 'E': 1094592, 'S': 1125101, 'W': 1057131}
# Direction: W3
# Way point: {'N': 296, 'E': 271, 'S': 250, 'W': 234}
# Progress: {'N': 1113900, 'E': 1094592, 'S': 1125101, 'W': 1057131}
# Direction: R90
# Way point: {'N': 234, 'E': 296, 'S': 271, 'W': 250}
# Progress: {'N': 1113900, 'E': 1094592, 'S': 1125101, 'W': 1057131}
# Direction: F23
# Way point: {'N': 234, 'E': 296, 'S': 271, 'W': 250}
# Progress: {'N': 1119282, 'E': 1101400, 'S': 1131334, 'W': 1062881}
# Direction: E1
# Way point: {'N': 234, 'E': 297, 'S': 271, 'W': 250}
# Progress: {'N': 1119282, 'E': 1101400, 'S': 1131334, 'W': 1062881}
# Direction: F25
# Way point: {'N': 234, 'E': 297, 'S': 271, 'W': 250}
# Progress: {'N': 1125132, 'E': 1108825, 'S': 1138109, 'W': 1069131}
# Direction: S2
# Way point: {'N': 234, 'E': 297, 'S': 273, 'W': 250}
# Progress: {'N': 1125132, 'E': 1108825, 'S': 1138109, 'W': 1069131}
# Direction: L180
# Way point: {'N': 273, 'E': 250, 'S': 234, 'W': 297}
# Progress: {'N': 1125132, 'E': 1108825, 'S': 1138109, 'W': 1069131}
# Direction: F80
# Way point: {'N': 273, 'E': 250, 'S': 234, 'W': 297}
# Progress: {'N': 1146972, 'E': 1128825, 'S': 1156829, 'W': 1092891}
# Direction: R180
# Way point: {'N': 234, 'E': 297, 'S': 273, 'W': 250}
# Progress: {'N': 1146972, 'E': 1128825, 'S': 1156829, 'W': 1092891}
# Direction: S5
# Way point: {'N': 234, 'E': 297, 'S': 278, 'W': 250}
# Progress: {'N': 1146972, 'E': 1128825, 'S': 1156829, 'W': 1092891}
# Direction: E3
# Way point: {'N': 234, 'E': 300, 'S': 278, 'W': 250}
# Progress: {'N': 1146972, 'E': 1128825, 'S': 1156829, 'W': 1092891}
# Direction: F90
# Way point: {'N': 234, 'E': 300, 'S': 278, 'W': 250}
# Progress: {'N': 1168032, 'E': 1155825, 'S': 1181849, 'W': 1115391}
# Direction: E4
# Way point: {'N': 234, 'E': 304, 'S': 278, 'W': 250}
# Progress: {'N': 1168032, 'E': 1155825, 'S': 1181849, 'W': 1115391}
# Direction: F60
# Way point: {'N': 234, 'E': 304, 'S': 278, 'W': 250}
# Progress: {'N': 1182072, 'E': 1174065, 'S': 1198529, 'W': 1130391}
# Direction: N4
# Way point: {'N': 238, 'E': 304, 'S': 278, 'W': 250}
# Progress: {'N': 1182072, 'E': 1174065, 'S': 1198529, 'W': 1130391}
# Direction: F75
# Way point: {'N': 238, 'E': 304, 'S': 278, 'W': 250}
# Progress: {'N': 1199922, 'E': 1196865, 'S': 1219379, 'W': 1149141}
# Direction: E3
# Way point: {'N': 238, 'E': 307, 'S': 278, 'W': 250}
# Progress: {'N': 1199922, 'E': 1196865, 'S': 1219379, 'W': 1149141}
# Direction: F10
# Way point: {'N': 238, 'E': 307, 'S': 278, 'W': 250}
# Progress: {'N': 1202302, 'E': 1199935, 'S': 1222159, 'W': 1151641}
# Direction: S3
# Way point: {'N': 238, 'E': 307, 'S': 281, 'W': 250}
# Progress: {'N': 1202302, 'E': 1199935, 'S': 1222159, 'W': 1151641}
# Direction: E1
# Way point: {'N': 238, 'E': 308, 'S': 281, 'W': 250}
# Progress: {'N': 1202302, 'E': 1199935, 'S': 1222159, 'W': 1151641}
# Direction: F8
# Way point: {'N': 238, 'E': 308, 'S': 281, 'W': 250}
# Progress: {'N': 1204206, 'E': 1202399, 'S': 1224407, 'W': 1153641}
# Direction: W5
# Way point: {'N': 238, 'E': 308, 'S': 281, 'W': 255}
# Progress: {'N': 1204206, 'E': 1202399, 'S': 1224407, 'W': 1153641}
# Direction: R90
# Way point: {'N': 255, 'E': 238, 'S': 308, 'W': 281}
# Progress: {'N': 1204206, 'E': 1202399, 'S': 1224407, 'W': 1153641}
# Direction: F20
# Way point: {'N': 255, 'E': 238, 'S': 308, 'W': 281}
# Progress: {'N': 1209306, 'E': 1207159, 'S': 1230567, 'W': 1159261}
# Direction: S3
# Way point: {'N': 255, 'E': 238, 'S': 311, 'W': 281}
# Progress: {'N': 1209306, 'E': 1207159, 'S': 1230567, 'W': 1159261}
# Direction: R90
# Way point: {'N': 281, 'E': 255, 'S': 238, 'W': 311}
# Progress: {'N': 1209306, 'E': 1207159, 'S': 1230567, 'W': 1159261}
# Direction: N2
# Way point: {'N': 283, 'E': 255, 'S': 238, 'W': 311}
# Progress: {'N': 1209306, 'E': 1207159, 'S': 1230567, 'W': 1159261}
# Direction: F41
# Way point: {'N': 283, 'E': 255, 'S': 238, 'W': 311}
# Progress: {'N': 1220909, 'E': 1217614, 'S': 1240325, 'W': 1172012}
# Direction: L90
# Way point: {'N': 255, 'E': 238, 'S': 311, 'W': 283}
# Progress: {'N': 1220909, 'E': 1217614, 'S': 1240325, 'W': 1172012}
# Direction: F8
# Way point: {'N': 255, 'E': 238, 'S': 311, 'W': 283}
# Progress: {'N': 1222949, 'E': 1219518, 'S': 1242813, 'W': 1174276}
# Direction: R270
# Way point: {'N': 238, 'E': 311, 'S': 283, 'W': 255}
# Progress: {'N': 1222949, 'E': 1219518, 'S': 1242813, 'W': 1174276}
# Direction: W1
# Way point: {'N': 238, 'E': 311, 'S': 283, 'W': 256}
# Progress: {'N': 1222949, 'E': 1219518, 'S': 1242813, 'W': 1174276}
# Direction: S1
# Way point: {'N': 238, 'E': 311, 'S': 284, 'W': 256}
# Progress: {'N': 1222949, 'E': 1219518, 'S': 1242813, 'W': 1174276}
# Direction: E2
# Way point: {'N': 238, 'E': 313, 'S': 284, 'W': 256}
# Progress: {'N': 1222949, 'E': 1219518, 'S': 1242813, 'W': 1174276}
# Direction: L180
# Way point: {'N': 284, 'E': 256, 'S': 238, 'W': 313}
# Progress: {'N': 1222949, 'E': 1219518, 'S': 1242813, 'W': 1174276}
# Direction: S4
# Way point: {'N': 284, 'E': 256, 'S': 242, 'W': 313}
# Progress: {'N': 1222949, 'E': 1219518, 'S': 1242813, 'W': 1174276}
# Direction: F52
# Way point: {'N': 284, 'E': 256, 'S': 242, 'W': 313}
# Progress: {'N': 1237717, 'E': 1232830, 'S': 1255397, 'W': 1190552}
# Direction: E5
# Way point: {'N': 284, 'E': 261, 'S': 242, 'W': 313}
# Progress: {'N': 1237717, 'E': 1232830, 'S': 1255397, 'W': 1190552}
# Direction: N2
# Way point: {'N': 286, 'E': 261, 'S': 242, 'W': 313}
# Progress: {'N': 1237717, 'E': 1232830, 'S': 1255397, 'W': 1190552}
# Direction: S3
# Way point: {'N': 286, 'E': 261, 'S': 245, 'W': 313}
# Progress: {'N': 1237717, 'E': 1232830, 'S': 1255397, 'W': 1190552}
# Direction: W1
# Way point: {'N': 286, 'E': 261, 'S': 245, 'W': 314}
# Progress: {'N': 1237717, 'E': 1232830, 'S': 1255397, 'W': 1190552}
# Direction: F67
# Way point: {'N': 286, 'E': 261, 'S': 245, 'W': 314}
# Progress: {'N': 1256879, 'E': 1250317, 'S': 1271812, 'W': 1211590}
# Direction: L90
# Way point: {'N': 261, 'E': 245, 'S': 314, 'W': 286}
# Progress: {'N': 1256879, 'E': 1250317, 'S': 1271812, 'W': 1211590}
# Direction: E3
# Way point: {'N': 261, 'E': 248, 'S': 314, 'W': 286}
# Progress: {'N': 1256879, 'E': 1250317, 'S': 1271812, 'W': 1211590}
# Direction: S2
# Way point: {'N': 261, 'E': 248, 'S': 316, 'W': 286}
# Progress: {'N': 1256879, 'E': 1250317, 'S': 1271812, 'W': 1211590}
# Direction: E2
# Way point: {'N': 261, 'E': 250, 'S': 316, 'W': 286}
# Progress: {'N': 1256879, 'E': 1250317, 'S': 1271812, 'W': 1211590}
# Direction: F30
# Way point: {'N': 261, 'E': 250, 'S': 316, 'W': 286}
# Progress: {'N': 1264709, 'E': 1257817, 'S': 1281292, 'W': 1220170}
# Direction: F12
# Way point: {'N': 261, 'E': 250, 'S': 316, 'W': 286}
# Progress: {'N': 1267841, 'E': 1260817, 'S': 1285084, 'W': 1223602}
# Direction: E3
# Way point: {'N': 261, 'E': 253, 'S': 316, 'W': 286}
# Progress: {'N': 1267841, 'E': 1260817, 'S': 1285084, 'W': 1223602}
# Direction: F11
# Way point: {'N': 261, 'E': 253, 'S': 316, 'W': 286}
# Progress: {'N': 1270712, 'E': 1263600, 'S': 1288560, 'W': 1226748}
# Direction: W4
# Way point: {'N': 261, 'E': 253, 'S': 316, 'W': 290}
# Progress: {'N': 1270712, 'E': 1263600, 'S': 1288560, 'W': 1226748}
# Direction: L90
# Way point: {'N': 253, 'E': 316, 'S': 290, 'W': 261}
# Progress: {'N': 1270712, 'E': 1263600, 'S': 1288560, 'W': 1226748}
# Direction: S4
# Way point: {'N': 253, 'E': 316, 'S': 294, 'W': 261}
# Progress: {'N': 1270712, 'E': 1263600, 'S': 1288560, 'W': 1226748}
# Direction: F5
# Way point: {'N': 253, 'E': 316, 'S': 294, 'W': 261}
# Progress: {'N': 1271977, 'E': 1265180, 'S': 1290030, 'W': 1228053}
# Direction: R90
# Way point: {'N': 261, 'E': 253, 'S': 316, 'W': 294}
# Progress: {'N': 1271977, 'E': 1265180, 'S': 1290030, 'W': 1228053}
# Direction: S5
# Way point: {'N': 261, 'E': 253, 'S': 321, 'W': 294}
# Progress: {'N': 1271977, 'E': 1265180, 'S': 1290030, 'W': 1228053}
# Direction: E2
# Way point: {'N': 261, 'E': 255, 'S': 321, 'W': 294}
# Progress: {'N': 1271977, 'E': 1265180, 'S': 1290030, 'W': 1228053}
# Direction: E3
# Way point: {'N': 261, 'E': 258, 'S': 321, 'W': 294}
# Progress: {'N': 1271977, 'E': 1265180, 'S': 1290030, 'W': 1228053}
# Direction: R90
# Way point: {'N': 294, 'E': 261, 'S': 258, 'W': 321}
# Progress: {'N': 1271977, 'E': 1265180, 'S': 1290030, 'W': 1228053}
# Direction: F37
# Way point: {'N': 294, 'E': 261, 'S': 258, 'W': 321}
# Progress: {'N': 1282855, 'E': 1274837, 'S': 1299576, 'W': 1239930}
# Direction: R90
# Way point: {'N': 321, 'E': 294, 'S': 261, 'W': 258}
# Progress: {'N': 1282855, 'E': 1274837, 'S': 1299576, 'W': 1239930}
# Direction: F64
# Way point: {'N': 321, 'E': 294, 'S': 261, 'W': 258}
# Progress: {'N': 1303399, 'E': 1293653, 'S': 1316280, 'W': 1256442}
# Direction: R90
# Way point: {'N': 258, 'E': 321, 'S': 294, 'W': 261}
# Progress: {'N': 1303399, 'E': 1293653, 'S': 1316280, 'W': 1256442}
# Direction: F68
# Way point: {'N': 258, 'E': 321, 'S': 294, 'W': 261}
# Progress: {'N': 1320943, 'E': 1315481, 'S': 1336272, 'W': 1274190}
# Direction: L90
# Way point: {'N': 321, 'E': 294, 'S': 261, 'W': 258}
# Progress: {'N': 1320943, 'E': 1315481, 'S': 1336272, 'W': 1274190}
# Direction: N1
# Way point: {'N': 322, 'E': 294, 'S': 261, 'W': 258}
# Progress: {'N': 1320943, 'E': 1315481, 'S': 1336272, 'W': 1274190}
# Direction: E2
# Way point: {'N': 322, 'E': 296, 'S': 261, 'W': 258}
# Progress: {'N': 1320943, 'E': 1315481, 'S': 1336272, 'W': 1274190}
# Direction: N4
# Way point: {'N': 326, 'E': 296, 'S': 261, 'W': 258}
# Progress: {'N': 1320943, 'E': 1315481, 'S': 1336272, 'W': 1274190}
# Direction: R180
# Way point: {'N': 261, 'E': 258, 'S': 326, 'W': 296}
# Progress: {'N': 1320943, 'E': 1315481, 'S': 1336272, 'W': 1274190}
# Direction: W4
# Way point: {'N': 261, 'E': 258, 'S': 326, 'W': 300}
# Progress: {'N': 1320943, 'E': 1315481, 'S': 1336272, 'W': 1274190}
# Direction: L90
# Way point: {'N': 258, 'E': 326, 'S': 300, 'W': 261}
# Progress: {'N': 1320943, 'E': 1315481, 'S': 1336272, 'W': 1274190}
# Direction: F68
# Way point: {'N': 258, 'E': 326, 'S': 300, 'W': 261}
# Progress: {'N': 1338487, 'E': 1337649, 'S': 1356672, 'W': 1291938}
# Direction: R90
# Way point: {'N': 261, 'E': 258, 'S': 326, 'W': 300}
# Progress: {'N': 1338487, 'E': 1337649, 'S': 1356672, 'W': 1291938}
# Direction: N5
# Way point: {'N': 266, 'E': 258, 'S': 326, 'W': 300}
# Progress: {'N': 1338487, 'E': 1337649, 'S': 1356672, 'W': 1291938}
# Direction: E2
# Way point: {'N': 266, 'E': 260, 'S': 326, 'W': 300}
# Progress: {'N': 1338487, 'E': 1337649, 'S': 1356672, 'W': 1291938}
# Direction: F54
# Way point: {'N': 266, 'E': 260, 'S': 326, 'W': 300}
# Progress: {'N': 1352851, 'E': 1351689, 'S': 1374276, 'W': 1308138}
# Direction: W2
# Way point: {'N': 266, 'E': 260, 'S': 326, 'W': 302}
# Progress: {'N': 1352851, 'E': 1351689, 'S': 1374276, 'W': 1308138}
# Direction: F84
# Way point: {'N': 266, 'E': 260, 'S': 326, 'W': 302}
# Progress: {'N': 1375195, 'E': 1373529, 'S': 1401660, 'W': 1333506}
# Direction: L90
# Way point: {'N': 260, 'E': 326, 'S': 302, 'W': 266}
# Progress: {'N': 1375195, 'E': 1373529, 'S': 1401660, 'W': 1333506}
# Direction: E3
# Way point: {'N': 260, 'E': 329, 'S': 302, 'W': 266}
# Progress: {'N': 1375195, 'E': 1373529, 'S': 1401660, 'W': 1333506}
# Direction: R90
# Way point: {'N': 266, 'E': 260, 'S': 329, 'W': 302}
# Progress: {'N': 1375195, 'E': 1373529, 'S': 1401660, 'W': 1333506}
# Direction: E2
# Way point: {'N': 266, 'E': 262, 'S': 329, 'W': 302}
# Progress: {'N': 1375195, 'E': 1373529, 'S': 1401660, 'W': 1333506}
# Direction: F29
# Way point: {'N': 266, 'E': 262, 'S': 329, 'W': 302}
# Progress: {'N': 1382909, 'E': 1381127, 'S': 1411201, 'W': 1342264}
# Direction: R90
# Way point: {'N': 302, 'E': 266, 'S': 262, 'W': 329}
# Progress: {'N': 1382909, 'E': 1381127, 'S': 1411201, 'W': 1342264}
# Direction: N1
# Way point: {'N': 303, 'E': 266, 'S': 262, 'W': 329}
# Progress: {'N': 1382909, 'E': 1381127, 'S': 1411201, 'W': 1342264}
# Direction: E2
# Way point: {'N': 303, 'E': 268, 'S': 262, 'W': 329}
# Progress: {'N': 1382909, 'E': 1381127, 'S': 1411201, 'W': 1342264}
# Direction: L90
# Way point: {'N': 268, 'E': 262, 'S': 329, 'W': 303}
# Progress: {'N': 1382909, 'E': 1381127, 'S': 1411201, 'W': 1342264}
# Direction: S5
# Way point: {'N': 268, 'E': 262, 'S': 334, 'W': 303}
# Progress: {'N': 1382909, 'E': 1381127, 'S': 1411201, 'W': 1342264}
# Direction: F90
# Way point: {'N': 268, 'E': 262, 'S': 334, 'W': 303}
# Progress: {'N': 1407029, 'E': 1404707, 'S': 1441261, 'W': 1369534}
# Direction: E2
# Way point: {'N': 268, 'E': 264, 'S': 334, 'W': 303}
# Progress: {'N': 1407029, 'E': 1404707, 'S': 1441261, 'W': 1369534}
# Direction: F11
# Way point: {'N': 268, 'E': 264, 'S': 334, 'W': 303}
# Progress: {'N': 1409977, 'E': 1407611, 'S': 1444935, 'W': 1372867}
# Direction: S3
# Way point: {'N': 268, 'E': 264, 'S': 337, 'W': 303}
# Progress: {'N': 1409977, 'E': 1407611, 'S': 1444935, 'W': 1372867}
# Direction: F99
# Way point: {'N': 268, 'E': 264, 'S': 337, 'W': 303}
# Progress: {'N': 1436509, 'E': 1433747, 'S': 1478298, 'W': 1402864}
# Direction: W3
# Way point: {'N': 268, 'E': 264, 'S': 337, 'W': 306}
# Progress: {'N': 1436509, 'E': 1433747, 'S': 1478298, 'W': 1402864}
# Direction: S5
# Way point: {'N': 268, 'E': 264, 'S': 342, 'W': 306}
# Progress: {'N': 1436509, 'E': 1433747, 'S': 1478298, 'W': 1402864}
# Direction: F94
# Way point: {'N': 268, 'E': 264, 'S': 342, 'W': 306}
# Progress: {'N': 1461701, 'E': 1458563, 'S': 1510446, 'W': 1431628}
# Direction: R90
# Way point: {'N': 306, 'E': 268, 'S': 264, 'W': 342}
# Progress: {'N': 1461701, 'E': 1458563, 'S': 1510446, 'W': 1431628}
# Direction: F36
# Way point: {'N': 306, 'E': 268, 'S': 264, 'W': 342}
# Progress: {'N': 1472717, 'E': 1468211, 'S': 1519950, 'W': 1443940}

# %%
result = abs(progress['S'] - progress['N']) + abs(progress['E'] - progress['W'])

# %%
result
# Out:
# 71504
